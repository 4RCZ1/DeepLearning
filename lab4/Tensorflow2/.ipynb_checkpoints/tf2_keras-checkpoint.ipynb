# %% [markdown]
# ---
# ---
# # Tensorflow 2 - sieci jednokierunkowe
# ---
# ---

# %% [markdown]
# # Bibliografia
#
# \begin{enumerate}
# \item \textit{S. Raschka, V. Mirjalili}, Python Machine learning i deep learning. Biblioteki scikit-learn i TensorFlow 2,
# Wydanie III, Helion, 2021.
# \item \textit{A. Geron}, Uczenie maszynowe z uzyciem Scikit-Learn i TensorFlow. Helion, 2018.
# \end{enumerate}

# %% [markdown]
# ##### Spis treści:
#
# [1. Prosty, testowy przykład sprawdzający działanie tensorflow/keras](#1.-Prosty,-testowy-przykład-sprawdzający-działanie-tensorflow/keras)
#
# [2. Moduł tf.data jako interfejs danych w TensorFlow](#2.-Moduł-tf.data-jako-interfejs-danych-w-TensorFlow)
#
# [3. Model Sequential](#3.-Model-Sequential)
#
# [4. Obliczanie gradientów za pomocą różniczkowania automatycznego i klasy GradientTape](#4.-Obliczanie-gradientów-za-pomocą-różniczkowania-automatycznego-i-klasy-GradientTape)
#
# [5. Tworzenie modelu przez dziedziczenie klasy Model](#5.-Tworzenie-modelu-przez-dziedziczenie-klasy-Model)
#
# [6. Model Functional](#6.-Model-Functional)
#
# [7. Tworzenie niestandardowych warstw Keras](#7.-Tworzenie-niestandardowych-warstw-Keras)
#
# [8. Estymatory](#8.-Estymatory)

# %%
# !pip3 install ann_visualizer
# !pip install graphviz
# !pip install wand
# !pip install MagickWand
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import pandas as pd
import sys
from IPython.display import display, Math, Latex
import sympy as sym
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from ann_visualizer.visualize import ann_viz;
# Out:
# Requirement already satisfied: ann_visualizer in c:\users\fraktal\anaconda3\lib\site-packages (2.5)
# Requirement already satisfied: graphviz in c:\users\fraktal\anaconda3\lib\site-packages (0.16)
# Requirement already satisfied: wand in c:\users\fraktal\anaconda3\lib\site-packages (0.6.6)
# Requirement already satisfied: MagickWand in c:\users\fraktal\anaconda3\lib\site-packages (0.2)

# %% [markdown]
# # 1. Prosty, testowy przykład sprawdzający działanie tensorflow/keras

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()#wczytanie danych mnist w keras
x_train, x_test = x_train / 255.0, x_test / 255.0

#print(x_train.shape)#wymiary danych treningowych
#print(x_train[0][15])#16-ty wiersz pierwszego obrazu


model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4785 - accuracy: 0.8586
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1562 - accuracy: 0.9536
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1102 - accuracy: 0.9670
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0868 - accuracy: 0.9739
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0723 - accuracy: 0.9778
# 313/313 [==============================] - 0s 987us/step - loss: 0.0797 - accuracy: 0.9761
# [0.07974115014076233, 0.9761000275611877]

# %% [markdown]
# # 2. Moduł tf.data jako interfejs danych w TensorFlow
#
# ## 2.1. Typ Dataset
#
# Obiekt tensor, listą Pythona oraz tablicę NumPy, można przekształcić za pomocą  funkcji <i>tf.data.Dataset.from_tensor_slices()</i> do obiektu typu [Dataset](https://www.tensorflow.org/api_docs/python/tf/data/Dataset).
#
# Funkcja ta zwraca obiekt klasy <i>Dataset</i>, dzięki któremu iterujemy po poszczególnych elementach
# wejściowego zestawu danych.

# %%
a = [1.2, 3.4, 7.5, 4.1, 5.0, 1.0]

ds = tf.data.Dataset.from_tensor_slices(a)

print(ds)

for item in ds:
    print(item)
# Out:
# <TensorSliceDataset shapes: (), types: tf.float32>
# tf.Tensor(1.2, shape=(), dtype=float32)
# tf.Tensor(3.4, shape=(), dtype=float32)
# tf.Tensor(7.5, shape=(), dtype=float32)
# tf.Tensor(4.1, shape=(), dtype=float32)
# tf.Tensor(5.0, shape=(), dtype=float32)
# tf.Tensor(1.0, shape=(), dtype=float32)

# %% [markdown]
# #### Obiekty Dataset umożliwiają wiele użytecznych operacji

# %%
#utworzenie  grup o rozmiarze 3 z tego zestawu danych - z 6-ciu danych powstaną 2 grupy 

ds_batch = ds.batch(3)

for i, elem in enumerate(ds_batch, 1):
    print('batch {}:'.format(i), elem.numpy())
# Out:
# batch 1: [1.2 3.4 7.5]
# batch 2: [4.1 5.  1. ]

# %%
#łączenie danych różnego typu typu w jedną krotkę typu Data set

tf.random.set_seed(1)

t_x = tf.random.uniform([4, 3], dtype=tf.float32)#tensor 2-go rzędu wymiaru 4x3
t_y = tf.range(4) #tensor 1-go rzędu wymiary 4x1
print(t_x,"\n")
print(t_y,"\n")

#Musi istnieć zgodność  w stosunku jeden do jednego pomiędzy odpowiednimi elementami obydwu tensorów - w tym przypadku 
#'zewnętrzne' ich wymiary wynoszą 4
    
#utworzenie obiektów Dataset z tensorów    
ds_x = tf.data.Dataset.from_tensor_slices(t_x)
ds_y = tf.data.Dataset.from_tensor_slices(t_y)
    
ds_joint = tf.data.Dataset.zip((ds_x, ds_y))#łączenie obiektów Dataset - utworzenie obiektu 4-elementowego 

print('Po połączeniu\n')
for example in ds_joint:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy())
# Out:
# tf.Tensor(
# [[0.16513085 0.9014813  0.6309742 ]
#  [0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]
#  [0.60489583 0.6366315  0.6144488 ]], shape=(4, 3), dtype=float32)
#
# tf.Tensor([0 1 2 3], shape=(4,), dtype=int32)
#
# Po połączeniu
#
#   x:  [0.16513085 0.9014813  0.6309742 ]   y:  0
#   x:  [0.4345461  0.29193902 0.64250207]   y:  1
#   x:  [0.9757855  0.43509948 0.6601019 ]   y:  2
#   x:  [0.60489583 0.6366315  0.6144488 ]   y:  3

# %%
#łączenie tensorów można równoważnie i skrótowo przeprowadzić za pomocą metody tf.data.Dataset.from_tensor_slices():

ds_joint = tf.data.Dataset.from_tensor_slices((t_x, t_y))

print('Po połączeniu\n')
for example in ds_joint:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy())
# Out:
# Po połączeniu
#
#   x:  [0.16513085 0.9014813  0.6309742 ]   y:  0
#   x:  [0.4345461  0.29193902 0.64250207]   y:  1
#   x:  [0.9757855  0.43509948 0.6601019 ]   y:  2
#   x:  [0.60489583 0.6366315  0.6144488 ]   y:  3

# %%
#skalowanie cech - dane ds_joint przeskalowane do zakresu [−1, 1]

ds_trans = ds_joint.map(lambda x, y: (x*2-1.0, y))

print('Po przeskalowaniu \n')
for example in ds_trans:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy())
# Out:
# Po przeskalowaniu
#
#   x:  [-0.6697383   0.80296254  0.26194835]   y:  0
#   x:  [-0.13090777 -0.41612196  0.28500414]   y:  1
#   x:  [ 0.951571   -0.12980103  0.32020378]   y:  2
#   x:  [0.20979166 0.27326298 0.22889757]   y:  3

# %%
#losowe potasowanie składowych obiektu Dataset

tf.random.set_seed(1)
ds = ds_joint.shuffle(buffer_size=len(t_x))

print('Po przetasowniu \n')
for example in ds:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy())
# Out:
# Po przetasowniu
#
#   x:  [0.9757855  0.43509948 0.6601019 ]   y:  2
#   x:  [0.4345461  0.29193902 0.64250207]   y:  1
#   x:  [0.16513085 0.9014813  0.6309742 ]   y:  0
#   x:  [0.60489583 0.6366315  0.6144488 ]   y:  3

# %% [markdown]
# <b>Uwaga o funkcji tasującej shuffle():</b>Metoda shuffle() wymaga argumentu o nazwie buffer_size, dzięki któremu określamy liczbę elementów zestawów danych pogrupowanych razem przed rozpoczęciem tasowania. Elementy bufora
# są losowo dobierane, a ich miejsce w buforze jest wyznaczane zgodnie z kolejnymi elementami
# w pierwotnym (nieprzetasowanym) zestawie danych. Z tego powodu, jeżeli wybierzemy
# małą wartość argumentu buffer_size, zestaw danych może zostać niedokładnie potasowany.
# Jeżeli zestaw danych jest mały, wybór względnie małego rozmiaru bufora może wpłynąć negatywnie
# na wydajność predykcyjną sieci neuronowej, gdyż zestaw danych może nie zostać
# całkiem losowo przetasowany. W praktyce jednak jest to właściwie nieodczuwalne podczas
# pracy ze względnie dużymi zestawami danych, z którymi mamy dość często do czynienia
# w modelach uczenia głębokiego. Ewentualnie, aby zapewnić pełną losowość w każdej epoce,
# wystarczy wybrać rozmiar bufora równy liczbie przykładów uczących, tak jak dokonaliśmy
# tego w powyższym listingu (buffer_size=len(t_x)).

# %%
ds = ds_joint.batch(3)

for example in ds:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy(),'\n')
    
it = iter(ds)

batch_x, batch_y = next(it)#pierwsza grupa 

print('Batch-x: \n', batch_x.numpy())

print('Batch-y:   ', batch_y.numpy(),'\n')

batch_x, batch_y = next(it)#druga niepełna grupa

print('Batch-x: \n', batch_x.numpy())

print('Batch-y:   ', batch_y.numpy())
# Out:
#   x:  [[0.16513085 0.9014813  0.6309742 ]
#  [0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]]   y:  [0 1 2]
#
#   x:  [[0.60489583 0.6366315  0.6144488 ]]   y:  [3]
#
# Batch-x:
#  [[0.16513085 0.9014813  0.6309742 ]
#  [0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]]
# Batch-y:    [0 1 2]
#
# Batch-x:
#  [[0.60489583 0.6366315  0.6144488 ]]
# Batch-y:    [3]

# %%
#operacja repeat()

ds = ds_joint.repeat(count=2)

for example in ds:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy(),'\n')
# Out:
#   x:  [0.16513085 0.9014813  0.6309742 ]   y:  0
#
#   x:  [0.4345461  0.29193902 0.64250207]   y:  1
#
#   x:  [0.9757855  0.43509948 0.6601019 ]   y:  2
#
#   x:  [0.60489583 0.6366315  0.6144488 ]   y:  3
#
#   x:  [0.16513085 0.9014813  0.6309742 ]   y:  0
#
#   x:  [0.4345461  0.29193902 0.64250207]   y:  1
#
#   x:  [0.9757855  0.43509948 0.6601019 ]   y:  2
#
#   x:  [0.60489583 0.6366315  0.6144488 ]   y:  3

# %%
#łączenie operacji: batch() -> repeat()

ds = ds_joint.batch(3).repeat(count=2)

for example in ds:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy(),'\n')
# Out:
#   x:  [[0.16513085 0.9014813  0.6309742 ]
#  [0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]]   y:  [0 1 2]
#
#   x:  [[0.60489583 0.6366315  0.6144488 ]]   y:  [3]
#
#   x:  [[0.16513085 0.9014813  0.6309742 ]
#  [0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]]   y:  [0 1 2]
#
#   x:  [[0.60489583 0.6366315  0.6144488 ]]   y:  [3]

# %%
#łączenie operacji: shuffle() -> batch() -> repeat() - pewien wzorzec dla procesu uczenia

ds = ds_joint.shuffle(4).batch(2).repeat(3)


for example in ds:
    print('  x: ', example[0].numpy(), 
          '  y: ', example[1].numpy(),'\n')
# Out:
#   x:  [[0.4345461  0.29193902 0.64250207]
#  [0.9757855  0.43509948 0.6601019 ]]   y:  [1 2]
#
#   x:  [[0.60489583 0.6366315  0.6144488 ]
#  [0.16513085 0.9014813  0.6309742 ]]   y:  [3 0]
#
#   x:  [[0.4345461  0.29193902 0.64250207]
#  [0.60489583 0.6366315  0.6144488 ]]   y:  [1 3]
#
#   x:  [[0.16513085 0.9014813  0.6309742 ]
#  [0.9757855  0.43509948 0.6601019 ]]   y:  [0 2]
#
#   x:  [[0.9757855  0.43509948 0.6601019 ]
#  [0.4345461  0.29193902 0.64250207]]   y:  [2 1]
#
#   x:  [[0.60489583 0.6366315  0.6144488 ]
#  [0.16513085 0.9014813  0.6309742 ]]   y:  [3 0]

# %% [markdown]
# ## 2.2. Tworzenie zestawu danych z plików umieszczonych w lokalnym magazynie dyskowym

# %% [markdown]
# Stworzymy zestaw danych z plików obrazów przechowywanych na dysku. Posłużymy się lokalnym katalogiem ze zdjęciami psów i kotów w formacie JPEG (trzy zdjęcia psów i trzy zdjęcia kotów).
#
# Na tym zestawie danych zaprezentujemy ogólny mechanizm tworzenia zestawu danych z przechowywanych plików. Wykorztsamy w tym celu dwa dodatkowe moduły TensorFlow:
#
# - tf.io - do odczytywania plików
# - tf.image do rozkodowania nieprzetworzonej zawartości oraz do zmiany rozmiarów obrazów
#
# <b>Uwaga</b>: Moduły tf.io oraz tf.image zawierają wele dodatkowych i przydatnych funkcji, których opis
# można znaleźć w oficjalnej dokumentacji:
# - [moduł tf.io](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/io)
# - [moduł tf.image]( https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/image)

# %%
#odczyt zawartości katalogu  z plikami - biblioteka pathlib oraz ich wizualizacja

import pathlib

imgdir_path = pathlib.Path('cat_dog_images')

file_list = sorted([str(path) for path in imgdir_path.glob('*.jpg')])

print(file_list)# lista plików - prefiksy nazw (dog, cat) mogą zostać wykorzystne do generowania etykiet klasyfikacyjnych

#wizualizacja
import os



fig = plt.figure(figsize=(10, 5))
for i,file in enumerate(file_list):
    img_raw = tf.io.read_file(file)#funkcja tf.io.read_file zwraca tensor, czyli zawiera m.in. składowe: shape oraz numpy
    #print(img_raw)
    img = tf.image.decode_image(img_raw)#dekoduje piksele na tablice 3 składowych rgb w języku [0,255]
    print('Image shape: ', img.shape)
    ax = fig.add_subplot(2, 3, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(img)# dokumentacja: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
    ax.set_title(os.path.basename(file), size=15)
    
plt.tight_layout()
plt.show()
# Out:
# ['cat_dog_images\\cat-01.jpg', 'cat_dog_images\\cat-02.jpg', 'cat_dog_images\\cat-03.jpg', 'cat_dog_images\\dog-01.jpg', 'cat_dog_images\\dog-02.jpg', 'cat_dog_images\\dog-03.jpg']
# Image shape:  (900, 1200, 3)
# Image shape:  (900, 1200, 3)
# Image shape:  (900, 742, 3)
# Image shape:  (800, 1200, 3)
# Image shape:  (800, 1200, 3)
# Image shape:  (900, 1200, 3)

# %%
#wygenerowanie tablicy etykiet dla plików

labels = [1 if 'dog' in os.path.basename(file) else 0 for file in file_list]
print(labels)
# Out:
# [0, 0, 0, 1, 1, 1]

# %%
# łączenie nazw plików  i etykiet w obiekt Dataset

ds_files_labels = tf.data.Dataset.from_tensor_slices((file_list, labels))

for item in ds_files_labels:
    print(item[0].numpy(), item[1].numpy())
# Out:
# b'cat_dog_images\\cat-01.jpg' 0
# b'cat_dog_images\\cat-02.jpg' 0
# b'cat_dog_images\\cat-03.jpg' 0
# b'cat_dog_images\\dog-01.jpg' 1
# b'cat_dog_images\\dog-02.jpg' 1
# b'cat_dog_images\\dog-03.jpg' 1

# %%
# funkcja pomocnicza wczytująca zawartość obrazu ze ścieżki pliku, rozkodowująca nieprzetworzoną treść 
# i zmieniająca rozmiary do pożądanej proporcji, np. 80×120 oraz normalizująca wartości składowych rgb do [0,1]

def load_and_preprocess(path, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [img_height, img_width])
    image /= 255.0

    return image, label

# %%
# skalowanie i normalizacja danych

img_width, img_height = 120, 80

ds_images_labels = ds_files_labels.map(load_and_preprocess)

# %%
#wizualizacja obrazów po normalizcaji i skalowaniu

fig = plt.figure(figsize=(10, 5))
for i,example in enumerate(ds_images_labels):
    print(example[0].shape, example[1].numpy())
    ax = fig.add_subplot(2, 3, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(example[0])
    ax.set_title('{}'.format(example[1].numpy()), 
                 size=15)
    
plt.tight_layout()
plt.show()
# Out:
# (80, 120, 3) 0
# (80, 120, 3) 0
# (80, 120, 3) 0
# (80, 120, 3) 1
# (80, 120, 3) 1
# (80, 120, 3) 1

# %% [markdown]
# ## 2.3. Pobieranie dostępnych zestawów danych z biblioteki tensorflow_datasets

# %%
import tensorflow_datasets as tfds

#funkcja list_builders generuje listę nazw dostępnych zestawów danych
print(len(tfds.list_builders()))
print(tfds.list_builders()[:5])
# Out:
# 278
# ['abstract_reasoning', 'accentdb', 'aeslc', 'aflw2k3d', 'ag_news_subset']

# %% [markdown]
# #### Istnieją dwa sposoby wczytywania zestawów:
#
# \begin{enumerate}
# \item Pierwsza technika jest trójetapowa:
# \begin{enumerate}
# \item Wywołanie konstruktora zestawu danych.
# \item Realizacja metody download_and_prepare().
# \item Wywołanie metody as_dataset().
# \end{enumerate}
# \item Druga strategia polega na wykorzystaniu funkcji load(), która za jednym zamachem realizuje wszystkie trzy powyższe etapy
# wcześniej etapy pobierania zestawu danych
# \end{enumerate}
# <p></p>
# Zrealizujmy pierwszy etap na przykładzie zestawu CelebA i wyświetlmy dostępny w bibliotece

# %%
# Technika 1 na zestawie mnist

# 1.1. wywołanie konstruktora zestawu mnist
mnist_bldr = tfds.builder('mnist')# wywołanie konstruktora zestawu mnist
print(type(mnist_bldr))

# Wyświetlenie różnych informacji o zestawie danych
print(mnist_bldr.info.features)
print('\n', 30*"=", '\n')
print(mnist_bldr.info.features.keys())#Cechy są przechowane jako słownik zawierający trzy klucze: 'image', 'landmarks' i 'attributes'.
print('\n', 30*"=", '\n')
print(mnist_bldr.info.features['image'])
print('\n', 30*"=", '\n')
print(mnist_bldr.info.features['label'])
print('\n', 30*"=", '\n')
print(mnist_bldr.info.citation)

# 1.2. wywołanie metody download_and_prepare() - załadowanie danych na  dysk
#utworzenie katalogu C:\Users\username\tensorflow_datasets\mnist\3.0.1.
mnist_bldr.download_and_prepare()

# 1.3. Wywołanie metody as_dataset() -  załadowanie  danych z dysku  jako tf.data.Datasets
datasets = mnist_bldr.as_dataset(shuffle_files=False)
datasets.keys()
# Out:
# <class 'tensorflow_datasets.image_classification.mnist.MNIST'>
# FeaturesDict({
#     'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })
#
#  ==============================
#
# dict_keys(['image', 'label'])
#
#  ==============================
#
# Image(shape=(28, 28, 1), dtype=tf.uint8)
#
#  ==============================
#
# ClassLabel(shape=(), dtype=tf.int64, num_classes=10)
#
#  ==============================
#
# @article{lecun2010mnist,
#   title={MNIST handwritten digit database},
#   author={LeCun, Yann and Cortes, Corinna and Burges, CJ},
#   journal={ATT Labs [Online]. Available: http://yann.lecun.com/exdb/mnist},
#   volume={2},
#   year={2010}
# }
# dict_keys(['train', 'test'])

# %%
#zdefiniowanie obiektu Dataset z danych treningowych
ds_train = datasets['train']
assert isinstance(ds_train, tf.data.Dataset)

example = next(iter(ds_train))
print(type(example))
print(example.keys())
# Out:
# <class 'dict'>
# dict_keys(['image', 'label'])

# %%
ds_train = ds_train.map(lambda item: 
     (item['image'], item['label']))

ds_train = ds_train.batch(10)
batch = next(iter(ds_train))
print(batch[0].shape, batch[1])

fig = plt.figure(figsize=(15, 6))
for i,(image,label) in enumerate(zip(batch[0], batch[1])):
    ax = fig.add_subplot(2, 5, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(image[:, :, 0], cmap='gray_r')
    ax.set_title('{}'.format(label), size=15)
    
plt.show()
# informacje w przypadku  ewentualnego ostrzeżenia: https://github.com/tensorflow/tensorflow/issues/37144
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E3C1B820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E3C1B820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000195E3C1B820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (10, 28, 28, 1) tf.Tensor([4 1 0 7 8 1 2 7 1 6], shape=(10,), dtype=int64)

# %%
#  Technika 2 na zestawie mnist

mnist, mnist_info = tfds.load('mnist', with_info=True,
                              shuffle_files=False)

print(mnist_info)

print(mnist.keys())
# Out:
# tfds.core.DatasetInfo(
#     name='mnist',
#     full_name='mnist/3.0.1',
#     description="""
#     The MNIST database of handwritten digits.
#     """,
#     homepage='http://yann.lecun.com/exdb/mnist/',
#     data_path='C:\\Users\\fraktal\\tensorflow_datasets\\mnist\\3.0.1',
#     download_size=11.06 MiB,
#     dataset_size=21.00 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=60000, num_shards=1>,
#     },
#     citation="""@article{lecun2010mnist,
#       title={MNIST handwritten digit database},
#       author={LeCun, Yann and Cortes, Corinna and Burges, CJ},
#       journal={ATT Labs [Online]. Available: http://yann.lecun.com/exdb/mnist},
#       volume={2},
#       year={2010}
#     }""",
# )
# dict_keys(['train', 'test'])

# %%
ds_train = mnist['train']

assert isinstance(ds_train, tf.data.Dataset)

ds_train = ds_train.map(lambda item: 
     (item['image'], item['label']))

ds_train = ds_train.batch(10)
batch = next(iter(ds_train))
print(batch[0].shape, batch[1])

fig = plt.figure(figsize=(15, 6))
for i,(image,label) in enumerate(zip(batch[0], batch[1])):
    ax = fig.add_subplot(2, 5, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(image[:, :, 0], cmap='gray_r')
    ax.set_title('{}'.format(label), size=15)
    
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E3BE6DC0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E3BE6DC0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000195E3BE6DC0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (10, 28, 28, 1) tf.Tensor([4 1 0 7 8 1 2 7 1 6], shape=(10,), dtype=int64)

# %% [markdown]
# # 3. Model Sequential
#
# Istotne informacje: https://www.tensorflow.org/guide/keras/sequential_model
#
# ##### Referencje:
#
# InputLayer:http://man.hubwiz.com/docset/TensorFlow.docset/Contents/Resources/Documents/api_docs/python/tf/keras/layers/InputLayer.html
#
# Dense: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense

# %% [markdown]
# ## 3.1. Ogólna koncepcja
#
# ### 3.1.1. Dodanie warstw
#
# Możemy to zrobić na dwa sposoby:
#
# - przekazanie listy warstw do konstruktora
# - używając funkcji <tt>add</tt>

# %%
# Sposób 1: Przekazanie listy warstw do konstruktora
model1 = keras.Sequential(
    [
        layers.InputLayer(input_shape=(4,)),#tensor wejściowy ma format 4-elementowego wektora
        layers.Dense(2, activation="relu"),#warstwa gęsta składająca się z 2 neuronów, z funkcją aktywacji ReLu
        layers.Dense(3, activation="relu"),#warstwa gęsta składająca się z 3 neuronów, z funkcją aktywacji ReLu
        layers.Dense(4),#warstwa gęsta składająca się z dwóch neuronów, z funkcją aktywacji Id (tak jest pomimo, że domyślnie activation=None )
    ]
)

# Sposób 2: Przekazanie listy warstw do konstruktora
model2 = keras.models.Sequential()
model2.add(layers.InputLayer(input_shape=(4,))),#tensor wejściowy ma format 4-elementowego wektora
model2.add(layers.Dense(2, activation="relu")),#warstwa gęsta składająca się z 2 neuronów, z funkcją aktywacji ReLu
model2.add(layers.Dense(3, activation="relu")),#warstwa gęsta składająca się z 3 neuronów, z funkcją aktywacji ReLu
model2.add(layers.Dense(4)),#warstwa gęsta składająca się z dwóch neuronów, z funkcją aktywacji Id (tak jest pomimo, że domyślnie activation=None )
# Out:
# (None,)

# %%
print(model1)
print(layers.InputLayer(input_shape=(4,)))
print(layers.Dense(2, activation="relu"))
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x00000195E5E0AB80>
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x00000195E6036F40>
# <tensorflow.python.keras.layers.core.Dense object at 0x00000195E5A48F70>

# %%
#Param wskazuje na ilość wag   dla warstw gęstych (warstwa gęsta 0 ma 4 wagi wejściowe i dodaje w każdym swoim neuronie 
#po jednej wadze bias - w efekcie każdy z dwóch neuronów warstwy gęstej 0 działa na 5 danych)
model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 9
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 16
# =================================================================
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 16
# =================================================================
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model1.layers[0].input_shape)
print(model1.layers[0].output_shape)
# Out:
# (None, 4)
# (None, 2)

# %%
print(model1.layers[0])
print(type(model1.layers[0].trainable_weights[0]))#wagi (w tym przypadku 'niezamrożone' warstw 0-1) są typu modyfikowalnego
print(model1.layers[0].trainable_weights[0])
# Out:
# <tensorflow.python.keras.layers.core.Dense object at 0x00000195E5A5B250>
# <class 'tensorflow.python.ops.resource_variable_ops.ResourceVariable'>
# <tf.Variable 'dense_6/kernel:0' shape=(4, 2) dtype=float32, numpy=
# array([[ 0.6585548 ,  0.26845598],
#        [ 0.02945518, -0.21783829],
#        [ 0.16180563, -0.90303636],
#        [-0.6447358 ,  0.40940332]], dtype=float32)>

# %%
#prosty sposób odczytu wszystkich wag i obciążeń
all_weights = model1.layers[0].get_weights()#10 wag z warstwy 0
weights = all_weights[0]
biases = all_weights[1]
print(all_weights)
print(weights)
print(biases)
# Out:
# [array([[ 0.6585548 ,  0.26845598],
#        [ 0.02945518, -0.21783829],
#        [ 0.16180563, -0.90303636],
#        [-0.6447358 ,  0.40940332]], dtype=float32), array([0., 0.], dtype=float32)]
# [[ 0.6585548   0.26845598]
#  [ 0.02945518 -0.21783829]
#  [ 0.16180563 -0.90303636]
#  [-0.6447358   0.40940332]]
# [0. 0.]

# %%
#Przypadek sieci z warstwą Flatten

model3 = keras.models.Sequential()

model3.add(keras.layers.Flatten(input_shape=[28, 28]))#warstwa Flatten (czyli warstwa 0) nie ma oczywiście wag wejściowych - nic nie liczy, tylko spłaszcza
model3.add(keras.layers.Dense(256, activation="relu"))
model3.add(keras.layers.Dense(128, activation="relu"))
model3.add(keras.layers.Dense(10, activation="softmax"))
print(model3.layers[0])
print(model3.layers[0].input_shape)
print(model3.layers[0].output_shape)
print(model3.layers[0].get_weights())# pusty wektor wag warstwy Flatten
# Out:
# <tensorflow.python.keras.layers.core.Flatten object at 0x00000195E60291C0>
# (None, 28, 28)
# (None, 784)
# []

# %%
#wybrane informacje z warstwy
info={'name':model1.layers[0].name, 'trainable_weights':model1.layers[0].trainable_weights}
print(info)
# Out:
# {'name': 'dense_6', 'trainable_weights': [<tf.Variable 'dense_6/kernel:0' shape=(4, 2) dtype=float32, numpy=
# array([[ 0.6585548 ,  0.26845598],
#        [ 0.02945518, -0.21783829],
#        [ 0.16180563, -0.90303636],
#        [-0.6447358 ,  0.40940332]], dtype=float32)>, <tf.Variable 'dense_6/bias:0' shape=(2,) dtype=float32, numpy=array([0., 0.], dtype=float32)>]}

# %% [markdown]
# ### 3.1.2. Wizualizacja struktury sieci

# %%
# Wizualizacja sieci: https://github.com/RedaOps/ann-visualizer (ann-visualizer używa graphviz: https://graphviz.org/)
#ann_viz(model1, title="Wizualizacja sieci gęstej", view=True, filename="dense_network.gv")

# %%
#wyświetlenie pdf w Jupyter notebook: moduły wand, Magickwand - trzeba również zainstalować ImageMagic w systemie operacyjnym

from wand.image import Image as WImage
img = WImage(filename='dense_network.gv.pdf')
img
# Out:
# <wand.image.Image: 8d3e012 'PDF' (472x594)>

# %%
#inny sposób wizualizacji - funkcja plot_model z biblioteki keras

from tensorflow.keras.utils import plot_model 

plot_model(model1, to_file='model1_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True,)

# %%
#model2 jest identyczny jak model1

plot_model(model2, to_file='model2_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True,)

# %%
plot_model(model3, to_file='model3_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True,)

# %% [markdown]
# ## 3.2.  Dobór funkcji aktywacji dla wielowarstwowych sieci neuronowych

# %% [markdown]
# ### 3.2.1.  Funkcja logistyczna
#
# Logistyczna funkcja aktywacji prawdopodobnie w największym
# stopniu odwzorowuje działanie rzeczywistej komórki nerwowej: możemy ją sobie wyobrazić
# jako prawdopodobieństwo pobudzenia neuronu. Logistyczna (sigmoidalna) funkcja aktywacji
# staje się jednak nieprzydatna w przypadku ujemnych danych wejściowych, ponieważ
# wówczas jej wartość byłaby zbliżona do zera. Jeśli wartość funkcji sigmoidalnej zbliża się do
# zera, sieć neuronowa uczy się bardzo powoli i zwiększa się ryzyko utknięcia algorytmu
# w lokalnym minimum funkcji kosztu na etapie trenowania. Dlatego analitycy często wybierają
# funkcję tangensa hiperbolicznego jako funkcję pobudzenia w warstwach ukrytych (zob. 3.2.3).
#
# Jak było to już pokazane funkcji logistycznej możemy używać do modelowania prawdopodobieństwa
# przynależności próby x do klasy pozytywnej (klasy 1) w klasyfikacji binarnej.
#
# #### Przykład:
# Załóżmy, że mamy do czynienia z modelem analizującym dwuwymiarowy
# punkt danych x  oraz zawierającym poniższe współczynniki wag przydzielone do
# wektora w (w0 jest jednostką obciążenia (punkt przecięcia z osią y, co oznacza, że x0 = 1):

# %%
import numpy as np

X = np.array([1, 1.4, 2.5]) ## pierwsza wartość musi być równa 1
w = np.array([0.4, 0.3, 0.5])

def net_input(X, w):
    return np.dot(X, w)

def logistic(z):
    return 1.0 / (1.0 + np.exp(-z))

def logistic_activation(X, w):
    z = net_input(X, w)
    return logistic(z)

print('P(y=1|x) = %.3f' % logistic_activation(X, w))
# Out:
# P(y=1|x) = 0.888

# %% [markdown]
# Otrzymamy wynik 0,888 interpretujemy jako 88,8% prawdopodobieństwa na przynależność próby x do klasy
# pozytywnej.
#
# <b>Uwaga</b> warstwa wyjściowa
# zawierająca wiele jednostek aktywacji logistycznej generuje w ogólnosci absurdalne, nieinterpretowalne
# wartości prawdopodobieństwa. W poniższym przykładzie na wejściu  warstwy (czyli w ogólności wyjściu poprzedniej warstwy ukrytej) podawane są  trzy wartości 0.1, 0.4, 0.6. Zakładamy, że należą one do trzech różnych klas, stąd na wyjściu generujemy 3 liczby. Jak widać, nie możemy interpretować otrzymanych wartości jako prawdopodobieństwa
# przynależności do klasy w problemie trójklasowym. Wynika to z tego, że ich suma nie jest
# równa 1.

# %%
# W : tablica, wymiary = [n_jednostek_wyjściowych, n_jednostek_ukrytych+1]
#   zwróć uwagę, że pierwsza kolumna zawiera jednostki obciążenia

W = np.array([[1.1, 1.2, 0.8, 0.4],
              [0.2, 0.4, 1.0, 0.2],
              [0.6, 1.5, 1.2, 0.7]])

# A : tablica, wymiary = [n_jednostek_ukrytych+1, n_przykładów]
#    zwróć uwagę, że pierwsza kolumna w tej tablicy musi być równa 1


A = np.array([[1, 0.1, 0.4, 0.6]])
Z = np.dot(W, A[0])
y_probas = logistic(Z)
print('Pobudzenie całkowite: \n', Z)

print('Jednostki wyjściowe:\n', y_probas)
# Out:
# Pobudzenie całkowite:
#  [1.78 0.76 1.65]
# Jednostki wyjściowe:
#  [0.85569687 0.68135373 0.83889105]

# %% [markdown]
# W rzeczywistości nie jest to duży problem, jeżeli używamy modelu jedynie do przewidywania
# etykiet klas, a nie prawdopodobieństw przynależności do poszczególnych klas. Jednym
# ze sposobów przewidywania etykiet klas z uzyskanych wcześniej jednostek wyjściowych
# jest wykorzystanie wartości maksymalnej:

# %%
y_class = np.argmax(Z, axis=0)
print('Przewidywana etykieta klas: %d' % y_class)
# Out:
# Przewidywana etykieta klas: 0

# %% [markdown]
# Jednak W pewnych sytuacjach przydaje się możliwość obliczenia sensownych wartości prawdopodobieństwa
# przynależności do klas podczas predykcji wieloklasowych. W dalszej części rozdziału
# przyjrzymy się uogólnieniu funkcji logistycznej, tzw. funkcji softmax, która świetnie
# nadaje się do wspomnianego zadania.

# %% [markdown]
# ### 3.2.2.  Funkcja softmax  - szacowanie prawdopodobieństw przynależności do klas w klasyfikacji wieloklasowej
#
# Funkcja softmax stanowi w istocie „miękką” odmianę funkcji argmax; dzięki niej otrzymujemy
# nie pojedynczy indeks klasy, lecz prawdopodobieństwo przynależności do każdej z nich.
# Zatem funkcja softmax umożliwia nam wyliczanie sensownych prawdopodobieństw przynależności
# do klas w konfiguracjach wieloklasowych (wielomianowa regresja logistyczna).
# Funkcja softmax zwraca wektor prawdopodobieństw przynależności danej próby o całkowitym pobudzeniu
# $z=(z_i)_1^M$ do zbioru M klas. Prawdopodobieństwo  przynależności do i-tej klasy jest wyliczane za pomocą wyrażenia normalizującego występującego w mianowniku
# — tj. sumy funkcji liniowych ważonych wykładniczo:
# $$
# p(z)_i =\varphi(z)_i = \frac{e^{z_i}}{\sum_{j=1}^Me^{z_i}}
# $$

# %%
def softmax(z):
    return np.exp(z) / np.sum(np.exp(z))

y_probas = softmax(Z)#Z jest z przykładu powyżej
print('Prawdopodobieństwa:\n', y_probas)

np.sum(y_probas)
# Out:
# Prawdopodobieństwa:
#  [0.44668973 0.16107406 0.39223621]
# 1.0

# %% [markdown]
# Jak widać, prawdopodobieństwa przynależności do klas sumują się teraz do wartości 1, co jest
# zgodne z oczekiwaniami. Warto również zwrócić uwagę, że przewidywana etykieta klas jest
# taka sama jak w przypadku użytej w regresji logistycznej funkcji argmax.
#
#
# Możemy myśleć o funkcji softmax jako o znormalizowanym wyniku, przydatnym do uzyskiwania
# wiarygodnych prognoz przynależności określonych instancji do wyznaczonych grup w środowiskach
# wieloklasowych. Zatem w trakcie tworzenia modelu klasyfikacji wieloklasowej w Tensorflow możemy za pomocą funkcji tf.keras.activations.softmax() oszacować prawdopodobieństwo
# przynależności do każdej klasy dla każdej grupy przykładów. Aby wykorzystać funkcję
# softmax w TensorFlow, przekształcimy zmienną Z w tensor i zarezerwujemy dodatkowy wymiar
# na rozmiar grupy ([dokumentacja funkcji tf.expand_dims](https://www.tensorflow.org/api_docs/python/tf/expand_dims)):

# %%
import tensorflow as tf

Z_tensor = tf.expand_dims(Z, axis=0)
tf.keras.activations.softmax(Z_tensor)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float64, numpy=array([[0.44668973, 0.16107406, 0.39223621]])>

# %% [markdown]
# ### 3.2.3.  Rozszerzanie zakresu wartości wyjściowych za pomocą funkcji tangensa hiperbolicznego
# Funkcja tangensa hiperbolicznego jak wiadomo definiowana jest przez formułę:
# $$
# \tanh(z) = \frac{e^z-e^{-z}}{e^z+e^{-z}}
# $$
# Przewagą funkcji tangensa hiperbolicznego nad funkcja logistyczną jest szerszy zakres wartości
# wyjściowych w zakresie przedziału otwartego (–1, 1), co poprawia zbieżność algorytmu wstecznej
# propagacji. Poniżej pokazano porównanie wykresów tych funkcji.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def tanh(z):
    e_p = np.exp(z)
    e_m = np.exp(-z)
    return (e_p - e_m) / (e_p + e_m)

z = np.arange(-5, 5, 0.005)
log_act = logistic(z)
tanh_act = tanh(z)
plt.ylim([-1.5, 1.5])
plt.xlabel('Pobudzenie całkowite $z$')
plt.ylabel('Aktywacja $\phi(z)$')
plt.axhline(1, color='black', linestyle=':')
plt.axhline(0.5, color='black', linestyle=':')
plt.axhline(0, color='black', linestyle=':')
plt.axhline(-0.5, color='black', linestyle=':')
plt.axhline(-1, color='black', linestyle=':')
plt.plot(z, tanh_act,
    linewidth=3, linestyle='--',
    label='Funkcja tanh')
plt.plot(z, log_act,
    linewidth=3,
    label='Funkcja logistyczna')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Funkcja tanh() jest wbudowana zarówno w numPy jak i Tensorflow:

# %%
np.tanh(z)
# Out:
# array([-0.9999092 , -0.99990829, -0.99990737, ...,  0.99990644,
#         0.99990737,  0.99990829])

# %%
import tensorflow as tf

tf.keras.activations.tanh(z)
# Out:
# <tf.Tensor: shape=(2000,), dtype=float64, numpy=
# array([-0.9999092 , -0.99990829, -0.99990737, ...,  0.99990644,
#         0.99990737,  0.99990829])>

# %% [markdown]
# Ponadto funkcja logistyczna jest również dostępna w Tensorflow, a także w SciPy:

# %%
from scipy.special import expit

expit(z)
# Out:
# array([0.00669285, 0.00672617, 0.00675966, ..., 0.99320669, 0.99324034,
#        0.99327383])

# %%
tf.keras.activations.sigmoid(z)
# Out:
# <tf.Tensor: shape=(2000,), dtype=float64, numpy=
# array([0.00669285, 0.00672617, 0.00675966, ..., 0.99320669, 0.99324034,
#        0.99327383])>

# %% [markdown]
# ### 3.2.4. Aktywacja za pomocą prostowanej jednostki liniowej (ReLU)
#
# Prostowana jednostka liniowa (ang. Rectified Linear Unit — ReLU) to kolejna funkcja aktywacji
# często wykorzystywana w głębokich sieciach neuronowych. Zanim spróbujemy ją
# zrozumieć, powinniśmy najpierw poznać problem zanikającego gradientu w funkcjach aktywacji
# tanh i logistycznej.
#
# W celu wyjaśnienia tego problemu załóżmy, że początkowo mamy pobudzenie całkowite
# o wartości $z_1 = 20$ które następnie ulega zmianie do wartości $z_2=25$. Po obliczeniu funkcji
# aktywacji tanh uzyskujemy wyniki $\varphi(z_1)=1.0$ i$\varphi(z_2)=1.0$ , co oznacza brak zmian na wyjściu
# (z powodu asymptotycznych własności funkcji tanh i błędów numerycznych).
#
# Możemy z tego wywnioskować, że pochodna funkcji aktywacji w stosunku do pobudzenia
# całkowitego maleje wraz ze wzrostem wartości z. W konsekwencji wyznaczanie wag w trakcie
# uczenia staje się bardzo powolne, ponieważ wartości gradientu mogą być bliskie zera. Rozwiązaniem
# tego problemu jest właśnie funkcja ReLU. W ujęciu matematycznym definiujemy ją
# następująco:
# $$
# \varphi(z)=max(0,z)
# $$
#
# Jednostka ReLU jest funkcją nieliniową, która nadaje się do trenowania złożonych funkcji za
# pomocą sieci neuronowych. Poza tym pochodna wartości ReLU (w odniesieniu do wejścia)
# jest zawsze równa 1 dla dodatnich wartości wejściowych. Rozwiązuje to zatem problem zanikającego
# gradientu, dzięki czemu funkcja ta przydaje się w głębokich sieciach neuronowych. W module
# TensorFlow możemy stosować funkcję ReLU następująco:

# %%
import tensorflow as tf

tf.keras.activations.relu(z)
# Out:
# <tf.Tensor: shape=(2000,), dtype=float64, numpy=array([0.   , 0.   , 0.   , ..., 4.985, 4.99 , 4.995])>

# %% [markdown]
# Wszystkie dostępne w module keras funkcje aktywacji są opisane na stronie [keras/activations](https://www.tensorflow.org/api_docs/python/tf/keras/activations)

# %% [markdown]
# ## 3.3. Przykład produkcyjny
#
# ## Tworzenie perceptronu wielowarstwowego klasyfikującego kwiaty z zestawu danych Iris
# =======================================================================================================================
#
# ### 3.3.1. Wczytanie danych

# %%
#wczytanie danych z datasets
import tensorflow_datasets as tfds

iris, iris_info = tfds.load('iris', with_info=True)

print(iris_info)
# Out:
# tfds.core.DatasetInfo(
#     name='iris',
#     full_name='iris/2.0.0',
#     description="""
#     This is perhaps the best known database to be found in the pattern recognition
#     literature. Fisher's paper is a classic in the field and is referenced
#     frequently to this day. (See Duda & Hart, for example.) The data set contains
#     3 classes of 50 instances each, where each class refers to a type of iris
#     plant. One class is linearly separable from the other 2; the latter are NOT
#     linearly separable from each other.
#     """,
#     homepage='https://archive.ics.uci.edu/ml/datasets/iris',
#     data_path='C:\\Users\\fraktal\\tensorflow_datasets\\iris\\2.0.0',
#     download_size=4.44 KiB,
#     dataset_size=7.62 KiB,
#     features=FeaturesDict({
#         'features': Tensor(shape=(4,), dtype=tf.float32),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=3),
#     }),
#     supervised_keys=('features', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=150, num_shards=1>,
#     },
#     citation="""@misc{Dua:2019 ,
#     author = "Dua, Dheeru and Graff, Casey",
#     year = "2017",
#     title = "{UCI} Machine Learning Repository",
#     url = "http://archive.ics.uci.edu/ml",
#     institution = "University of California, Irvine, School of Information and Computer Sciences"
#     }""",
# )

# %% [markdown]
# ### 3.3.2. Tasowanie danych
#
# Jeżeli zestaw danych nie był potasowany,
# możemy teraz to zrobić. Musimy jednak bardzo uważać, ponieważ mogą zostać wymieszane
# przykłady uczące z testowymi, co jest niedopuszczalne w uczeniu maszynowym. Aby tego uniknąć,
# musimy wyznaczyć argument reshuffle_each_iteration=False w metodzie .shuffle().
# Kod podziału zestawu danych na zbiory uczący/testowy wygląda następująco:

# %%
tf.random.set_seed(1)

ds_orig = iris['train']
ds_orig = ds_orig.shuffle(150, reshuffle_each_iteration=False)

print(next(iter(ds_orig)))

ds_train_orig = ds_orig.take(100)
ds_test = ds_orig.skip(100)
# Out:
# {'features': <tf.Tensor: shape=(4,), dtype=float32, numpy=array([6.5, 3. , 5.2, 2. ], dtype=float32)>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=2>}

# %%
## sprawdza liczbę przykładów:

n = 0
for example in ds_train_orig:
    n += 1
print(n)


n = 0
for example in ds_test:
    n += 1
print(n)
# Out:
# 100
# 50

# %% [markdown]
# ### 3.3.3. Łączenie danych z etykietami
#
# Kolejnym etapem jest wprowadzenie przekształcenia polegającego na uzyskaniu krotki ze słownika za pomocą metody .map():

# %%
ds_train_orig = ds_train_orig.map(
    lambda x: (x['features'], x['label']))

ds_test = ds_test.map(
    lambda x: (x['features'], x['label']))

next(iter(ds_train_orig))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E719CA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E719CA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000195E719CA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E728FF70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x00000195E728FF70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x00000195E728FF70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (<tf.Tensor: shape=(4,), dtype=float32, numpy=array([6.5, 3. , 5.2, 2. ], dtype=float32)>,
#  <tf.Tensor: shape=(), dtype=int64, numpy=2>)

# %% [markdown]
# ### 3.3.4. Tworzenie warstw sieci
#
# Chcemy tu zdefiniować model zawierający
# dwie warstwy ukryte. Pierwsza z nich otrzymuje na wejściu cztery cechy i rzutuje je na 16 neuronów.
# Druga warstwa otrzymuje na wejściu wynik poprzedniej warstwy (o rozmiarze 16) i rzutuje
# je na trzy neurony wyjściowe, ponieważ dysponujemy tyloma etykietami klas.
#
# W pierwszej warstwie wprowadziliśmy sigmoidalną funkcję aktywacji, natomiast w ostatniej
# (wyjściowej) umieściliśmy funkcję softmax. Funkcja softmax w ostatniej warstwie jest stosowana
# w zadaniach klasyfikacji wieloklasowej, gdyż mamy w naszym przypadku trzy etykiety klas
# (wyjaśnia to, dlaczego ostatnia warstwa zawiera trzy neurony).

# %%
iris_model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='sigmoid', 
                          name='fc1', input_shape=(4,)),
    tf.keras.layers.Dense(3, name='fc2', activation='softmax')])

iris_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 16)                80
# _________________________________________________________________
# fc2 (Dense)                  (None, 3)                 51
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3.3.5. Kompilacja sieci - funkcja compile()
#
# W istocie funkcja ta pełni jedynie rolę definicji trzech obliczeniowych parametrów sieci neuronowej: określa funkcję straty,
# algorytm optymalizacji oraz metodę obliczania jakości sieci (metryka):

# %%
iris_model.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %% [markdown]
# Parametry te są opisane w dokumentacji:
#
# - [Funkcje straty w Keras](https://keras.io/api/losses/)
#
# - [Metryki w Keras](https://keras.io/api/metrics/)
#
# - [Optymalizatory w Keras](https://keras.io/api/optimizers/)

# %% [markdown]
# ### 3.3.6. Uczenie sieci - funkcja fit()
#
# Funkcja fit w ogólności specyfikuje dużą ilość parametrów (zob. [dokumentacja](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit)), ale zwykle podajemy tylko kilka: dane treningowe, etykiety, dane walidacyjne, rozmiar batch'a oraz ilość epok.
#
# Ze względu na sporo niejasności w rozróżnianu danych testowych i walidacyjnych odsyłamy tu do dobrego wyjaśnienia tych pojęć
# [Test_vs_validation](file:///C:/Users/fraktal/Downloads/What%20is%20the%20Difference%20Between%20Test%20and%20Validation%20Datasets_.html)
#
# Pojęcia epoki i rozmiaru batch'a były wyjaśnione przy implementacji MLP w pliku [nn_1.ipynb](nn_1.ipynb). Przypomnijmy tylko, że wagi sieci są uaktualniane raz na 1 batch, a jej wydajność (metryka) jest obliczana po przejściu całej epoki.

# %%
num_epochs = 100
training_size = 100
batch_size = 2
steps_per_epoch = np.ceil(training_size / batch_size)

ds_train = ds_train_orig.shuffle(buffer_size=training_size)
ds_train = ds_train.repeat()
ds_train = ds_train.batch(batch_size=batch_size)
ds_train = ds_train.prefetch(buffer_size=1000)


history = iris_model.fit(ds_train, epochs=num_epochs,
                         steps_per_epoch=steps_per_epoch, 
                         verbose=0)
print(history)
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x00000195E5A5B550>

# %% [markdown]
# Zwracana historia zmiennych przechowuje wartości funkcji straty uczenia i dokładności uczenia
# (wyznaczyliśmy te wskaźniki w iris_model.compile()) po każdej epoce. Możemy dzięki temu
# zwizualizować krzywe uczenia w następujący sposób:

# %%
hist = history.history

fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Funkcja straty uczenia', size=15)
ax.set_xlabel('Epoka', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Dokładność uczenia', size=15)
ax.set_xlabel('Epoka', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('r13-cls-krzywa-uczenia.pdf')

plt.show()

# %% [markdown]
# ### 3.3.7. Ocena wytrenowanego modelu za pomocą danych testowych

# %%
results = iris_model.evaluate(ds_test.batch(50), verbose=0)
print('F. straty (test): {:.4f}   Dokładność (test): {:.4f}'.format(*results))
# Out:
# F. straty (test): 0.1483   Dokładność (test): 0.9800

# %% [markdown]
# ### 3.3.8. Zapisywanie  wyuczonego modelu
#
# Możemy zapisywać wytrenowane modele na dysk do późniejszego użytku. Dokonujemy tego
# następująco:

# %%
iris_model.save('iris-klasyfikator.h5', 
                overwrite=True,
                include_optimizer=True,
                save_format='h5')

#iris_model.to_json()

# %% [markdown]
# Pierwszą opcją jest nazwa pliku. Wywołanie metody iris_model.save() spowoduje zapisanie
# zarówno architektury modelu, jak i wszystkich wyuczonych parametrów. Jeśli jednak chcesz
# zapisać tylko architekturę, możesz skorzystać z metody iris_model.to_json(), która zapisuje
# konfigurację modelu w formacie JSON. Ewentualnie możesz także zapisać tylko wagi modelu
# za pomocą wywołania metody iris_model.save_weights(). Atrybut save_format może przyjmować
# wartości 'h5' (format HDF5) lub 'tf' (format TensorFlow).
#
# ### 3.3.9. Wczytywanie wyuczonego modelu
#
# Wczytajmy teraz zapisany model. Zapisaliśmy zarówno strukturę modelu, jak i wagi, zatem możemy
# z łatwością odtworzyć i wczytać parametry za pomocą jednego wiersza kodu:

# %%
iris_model_new = tf.keras.models.load_model('iris-klasyfikator.h5')

iris_model_new.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 16)                80
# _________________________________________________________________
# fc2 (Dense)                  (None, 3)                 51
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Na koniec oceńmy ten wczytany model na zbiorze testowym, aby sprawdzić, czy rezultaty będą
# takie same jak poprzednio:

# %%
results = iris_model.evaluate(ds_test.batch(50), verbose=0)
print('F. straty (test): {:.4f}   Dokładność (test): {:.4f}'.format(*results))
# Out:
# F. straty (test): 0.1483   Dokładność (test): 0.9800

# %% [markdown]
# ### 3.3.10. Wykorzystanie wyuczonego modelu do nowych danych¶
#
# Aby przewidywać wartości zmiennej celu na nowych punktach danych, możemy użyć metody
# predict(). Załóżmy na potrzeby omawianego przykładu, że zbiór testowy reprezentuje zestaw
# nowych, nieoznakowanych punktów danych.
#
# Zwróć uwagę, że w rzeczywistych zadaniach przewidywania funkcja wejściowa będzie musiała
# zwracać jedynie zestaw danych składający się z cech przy założeniu, że etykiety są niedostępne.
# W naszym przypadku skorzystamy po prostu z tej samej funkcji wejściowej, co podczas oceniania
# modelu; otrzymamy w ten sposób przewidywania dla każdego przykładu:

# %%
pred_res = iris_model.predict(ds_test.batch(50))
y_test
#pred_res
#actual = np.argmax(y_test,axis=1)
#predicted = np.argmax(y_pred,axis=1)
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ## 3.4. Rozwiązywanie problemu klasyfikacji XOR
#
# Klasyfikacja XOR stanowi klasyczny problem analizowania pojemności modelu w odniesieniu
# do określania nieliniowej granicy decyzyjnej pomiędzy dwiema klasami. Wygenerujemy
# przykładowy zestaw danych składający się z 200 przykładów uczących losowanych z jednostajnego
# rozkładu w przedziale $[−1, 1)$, zawierający dwie cechy $(x_0, x_1)$. Następnie wybierzemy
# etykietę podstawową dla przykładu uczącego i zgodnie z następującą regułą:
# $$
# y^{(i)}=\left\{
# \begin{array}{ll}
# 0 &\hbox{jeżeli } x_0^{(i)}\cdot x_1^{(i)}<0 \\
# 1 &\hbox{jeżeli } x_0^{(i)}\cdot x_1^{(i)}\geq 0
# \end{array}
# \right.
# $$
# Połowę danych (100 przykładów) wykorzystamy do uczenia, a drugą połowę przeznaczymy
# na walidację.
#
# ### 3.4.1. Tworzenie i wizualizacja danych
#
# Kod generujący zestaw danych i rozdzielający go na zbiory uczący oraz walidacyjny
# wygląda następująco:

# %%
tf.random.set_seed(1)
np.random.seed(1)

x = np.random.uniform(low=-1, high=1, size=(200, 2))
y = np.ones(len(x))
y[x[:, 0] * x[:, 1]<0] = 0

x_train = x[:100, :]
y_train = y[:100]
x_valid = x[100:, :]
y_valid = y[100:]

fig = plt.figure(figsize=(6, 6))
plt.plot(x[y==0, 0], 
         x[y==0, 1], 'o', alpha=0.75, markersize=10)
plt.plot(x[y==1, 0], 
         x[y==1, 1], '<', alpha=0.75, markersize=10)
plt.xlabel(r'$x_1$', size=15)
plt.ylabel(r'$x_2$', size=15)
plt.show()

# %% [markdown]
# ### 3.4.2. Definiowanie modelu - pierwsze podejście
#
# Budujemy sieć zawierającą jedną warstwę. Całkowita liczba parametrów w modelu wynosi 3: macierz
# wag (jądro) o rozmiarze 2×1 i wektor obciążeń o rozmiarze 1.

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, 
                                input_shape=(2,), 
                                activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3.4.3. Kompilacja i trenowanie modelu - pierwsze podejście
#
# Model  wyuczymy przez 200 epok z wyznaczonym rozmiarem grupy równym 2:

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, verbose=0)

# %% [markdown]
# ### 3.4.4. Wizualizacja wyników - biblioteka MLxtend

# %%
from mlxtend.plotting import plot_decision_regions

history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['F. straty uczenia', 'F. straty walidacji'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Dokładność (uczenie)', 'Dokładność (walidacja)'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 3)
plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),
                      clf=model)
ax.set_xlabel(r'$x_1$', size=15)
ax.xaxis.set_label_coords(1, -0.025)
ax.set_ylabel(r'$x_2$', size=15)
ax.yaxis.set_label_coords(-0.025, 1)
plt.show()
# Out:
# <ipython-input-105-ecd56592d632>:19: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),

# %% [markdown]
# Jak widać, prosty model pozbawiony warstw ukrytych jest w stanie wyznaczyć jedynie liniową
# granicę decyzyjną i nie jest w stanie rozwiązać problemu XOR. W rezultacie możemy zauważyć,
# że wartości funkcji straty zarówno dla zbioru uczącego, jak i walidacyjnego są bardzo duże,
# a dokładność klasyfikacji okazuje się niewielka.
#
# W celu uzyskania nieliniowej granicy decyzyjnej możemy dodać przynajmniej jedną warstwę
# ukrytą zawierającą nieliniową funkcję aktywacji. Zgodnie z twierdzeniem o aproksymacji
# uniwersalnej jednokierunkowa sieć neuronowa z jedną warstwą ukrytą i względnie dużą
# liczbą jednostek ukrytych może w miarę dobrze przybliżać dowolne funkcje ciągłe. Dlatego
# jednym z rozwiązań problemu XOR w satysfakcjonujący sposób jest dołączenie warstwy
# ukrytej i porównywanie różnych liczb jednostek ukrytych aż do zaobserwowania właściwych
# wyników na zbiorze walidacyjnym. Dodawanie kolejnych jednostek ukrytych jest równoważne
# zwiększaniu szerokości warstwy.
#
# Możemy ewentualnie dodać więcej warstw ukrytych, czym zwiększymy głębokość modelu.
# Zaletą zwiększenia głębokości zamiast szerokości modelu jest mniejsza liczba parametrów
# wymaganych do uzyskania porównywalnej pojemności. Z drugiej strony narażamy się wtedy
# na ryzyko eksplodujących/zanikających gradientów, przez co trudniej jest trenować model
# głęboki.
#
# W ramach ćwiczenia dodaj jedną, dwie, trzy i cztery warstwy ukryte, każdą zawierającą
# cztery jednostki ukryte. W poniższym przykładzie przyjrzymy się wynikom jednokierunkowej
# sieci neuronowej, zawierającej trzy warstwy ukryte:
#
# ### 3.4.5. Podejście drugie - model z trzema warstwami ukrytymi

# %%
tf.random.set_seed(1)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=4, input_shape=(2,), activation='relu'))
model.add(tf.keras.layers.Dense(units=4, activation='relu'))
model.add(tf.keras.layers.Dense(units=4, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

model.summary()

## kompilacja:
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

## uczenie:
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, verbose=0)

history = hist.history
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 4)                 12
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_19 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['F. straty uczenia', 'F. straty walidacji'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Dokładność (uczenie)', 'Dokładność (walidacja)'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 3)
plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),
                      clf=model)
ax.set_xlabel(r'$x_1$', size=15)
ax.xaxis.set_label_coords(1, -0.025)
ax.set_ylabel(r'$x_2$', size=15)
ax.yaxis.set_label_coords(-0.025, 1)
plt.show()
# Out:
# <ipython-input-107-be430ba32df6>:15: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),

# %% [markdown]
# Widzimy teraz, że model jest w stanie wyznaczyć nieliniową granicę decyzyjną dla tych danych
# i osiąga stuprocentową dokładność na zbiorze uczącym. Dokładność dla zbioru walidacyjnego
# wynosi 95%, co wskazuje na nieznaczne przetrenowanie modelu.

# %% [markdown]
# ## 4. Obliczanie gradientów za pomocą różniczkowania automatycznego i klasy GradientTape
#
# Gradienty są używane w sieciach neuronowych w algorytmie propagacji wstecznej. Nają jednak również  inne zastosowania, takie jak diagnozowanie sieci; możemy dzięki nim sprawdzać, dlaczego model sieci neuronowej uzyskuje określoną
# predykcję dla przykładu testowego. Poniżej pokazano jak  obliczać gradienty
# w odniesieniu do pewnych zmiennych.

# %% [markdown]
# ### 4.1. Obliczanie gradientów funkcji straty w odniesieniu do zmiennych modyfikowalnych
#
# Moduł TensorFlow obsługuje mechanizm różniczkowania automatycznego (ang. automatic
# differentiation), który możemy traktować jako implementację reguły łańcuchowej (ang. chain rule)
# obliczania gradientów funkcji zagnieżdżonych (zob. [Automatic differentiation](https://en.wikipedia.org/wiki/Automatic_differentiation)). Podczas definiowania szeregu operacji, w wyniku
# których otrzymujemy jakiś wynik albo nawet tensory pośrednie, TensorFlow dostarcza kontekst
# obliczania gradientów tych obliczonych tensorów w odniesieniu do jego węzłów zależnych
# w grafie obliczeniowym.
# W celu obliczenia tych gradientów musimy „rejestrować” obliczenia
# poprzez klasę <b>tf.GradientTape</b>.
#
# Rozpatrzy prosty  przykład obliczający wzór $z = wx+b$ i zdefiniujemy
# funkcję straty jako kwadrat straty pomiędzy zmienną celu a predykcją: $strata = (y−z)^2$.
# W bardziej ogólnym przypadku, w którym dysponujemy wieloma przewidywaniami i zmiennymi
# celu, funkcję straty obliczamy jako sumę kwadratów błędu:
# $$
# Strata=\sum_i(y_i−z_i)^2
# $$
#
# Aby zaimplementować ten mechanizm w TensorFlow, zdefiniujemy parametry modelu, $w$ i $b$, jako
# zmienne, a dane wejściowe, $x$ i $y$, jako tensory. Umieścimy operacje obliczania zmiennej $z$
# i funkcji straty w kontekście tf.GradientTape:

# %%
import tensorflow as tf

w = tf.Variable(1.0)
b = tf.Variable(0.5)
print(w.trainable, b.trainable)

x = tf.convert_to_tensor([1.4])#niemodyfikowalne
y = tf.convert_to_tensor([2.1])#niemodyfikowalne

with tf.GradientTape() as tape:
    z = tf.add(tf.multiply(w, x), b)
    loss = tf.reduce_sum(tf.square(y - z))

dloss_dw = tape.gradient(loss, w)

tf.print('dS/dw : ', dloss_dw)
# Out:
# True True
# dS/dw :  -0.559999764

# %%
# sprawdzanie obliczonego gradientu
#tf.print(-2*x * (-b - w*x + y))

tf.print(2*x * ((w*x + b) - y))
# Out:
# [-0.559999764]

# %% [markdown]
# ### 4.2. Obliczanie gradientów w odniesieniu do tensorów niemodyfikowalnych
#
# Aby umożliwić obsługę zmiennych niemodyfikowalnych i innych obiektów Tensor,
# musimy umożliwić ich monitorowanie poprzez wprowadzenie funkcji tape.watch(). Na przykład,
# jeżeli chcemy obliczyć $\frac{\partial Strata}{\partial x}$, odpowiedzialny za to kod będzie wyglądał następująco:

# %%
with tf.GradientTape() as tape:
    tape.watch(x)
    z = tf.add(tf.multiply(w, x), b)
    loss = tf.square(y - z)

dloss_dx = tape.gradient(loss, x)

tf.print('dS/dx:', dloss_dx)
# Out:
# dS/dx: [-0.399999857]

# %%
# sprawdzanie obliczonego gradientu
tf.print(2*w * ((w*x + b) - y))
# Out:
# [-0.399999857]

# %% [markdown]
# ### 4.3. Przechowywanie zasobów na obliczanie wielu gradientów
#
# Domyślnie podczas monitorowania obliczeń w kontekście klasy tf.GradientTape taśma będzie
# przechowywać zasoby jedynie na obliczenia jednego gradientu. Na przykład po jednokrotnym
# wywołaniu tape.gradient() zasoby zostaną zwolnione, a taśma będzie wyczyszczona. Jeśli
# więc chcesz obliczyć większą liczbę gradientów musimy zwiększyć trwałość taśmy za pomocą atrybutu `persistent=True`

# %%
with tf.GradientTape(persistent=True) as tape:
    z = tf.add(tf.multiply(w, x), b)
    loss = tf.reduce_sum(tf.square(y - z))

dloss_dw = tape.gradient(loss, w)
dloss_db = tape.gradient(loss, b)

tf.print('dS/dw:', dloss_dw)
tf.print('dS/db:', dloss_db)
# Out:
# dS/dw: -0.559999764
# dS/db: -0.399999857

# %% [markdown]
# ### 4.4. Aktualizowanie zmiennych: `optimizer.apply_gradients()`
#
# Jeżeli obliczamy gradienty funkcji straty w odniesieniu do parametrów modelu,
# możemy zdefiniować optymalizator i zastosować gradienty w celu zoptymalizowania parametrów
# za pomocą interfejsu tf.keras, np.:

# %%
optimizer = tf.keras.optimizers.SGD()

optimizer.apply_gradients(zip([dloss_dw, dloss_db], [w, b]))

tf.print('Zaktualizowana waga:', w)
tf.print('Zaktualizowane obciążenie:', b)
# Out:
# Zaktualizowana waga: 1.0056
# Zaktualizowane obciążenie: 0.504

# %% [markdown]
# Pierwotnie waga i obciążenie jednostkowe miały wartości, odpowiednio, w = 1.0
# i b = 0.5, natomiast po zastosowaniu gradientów funkcji straty w odniesieniu do parametrów
# modelu wartości zmieniły się na w = 1,0056 i b = 0,504.

# %% [markdown]
# ## 5. Tworzenie modelu przez dziedziczenie klasy Model

# %% [markdown]
# ### 5.1. Tworzenie modelu regresji liniowej
#
# Utworzymy prosty model rozwiązujący problem regresji liniowej.
#
# #### 5.1.1. Tworzenie i wizualizacja danych:

# %%
X_train = np.arange(10).reshape((10, 1))
y_train = np.array([1.0, 1.3, 3.1,
                    2.0, 5.0, 6.3,
                    6.6, 7.4, 8.0,
                    9.0])


plt.plot(X_train, y_train, 'o', markersize=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### 5.1.2. Standaryzacja  cech i utworzenie obiektu Dataset:

# %%
X_train_norm = (X_train - np.mean(X_train))/np.std(X_train)

ds_train_orig = tf.data.Dataset.from_tensor_slices(
    (tf.cast(X_train_norm, tf.float32),
     tf.cast(y_train, tf.float32)))

# %% [markdown]
# #### 5.1.3. Zdefiniowanie modelu
#
# Idea regresji liniowej została wyjaśniona przy okazji omawiania Perceptronu (prosty model z = wx+b). W celu jej realizacji zdefiniujemy nową klasę wywodzącą się z klasy
# tf.keras.Model. Dzięki tworzeniu podklas z klasy tf.keras.Model możemy używać narzędzi
# Keras do tworzenia, uczenia i oceniania modelu.
#
# Utworzona sieć będzie zawierała jedynie jedną warstwę (wejściową). W konstruktorze klasy zdefiniujemy parametry modelu, $w$ i $b$, czyli wagę i obciążenie. W ogólności w konstruktorze __init__() definiujemy warstwy jako atrybuty klasy,
# dzięki czemu możemy uzyskać do nich dostęp poprzez atrybut odniesienia self.
#
# W klasie definiujemy metodę call() do określenia sposobu generowania danych wyjściowych z danych wejściowych - metoda call() służy do określania przebiegu sygnału w przód, czyli w ogólnosci wewnątrz metody call() określamy sposób używania zdefiniowanych w konstruktorze  warstw w przebiegu sygnału w przód.

# %%
class MyModel(tf.keras.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.w = tf.Variable(0.0, name='waga')
        self.b = tf.Variable(0.0, name='obciazenie')

    def call(self, x):
        return self.w*x + self.b

# %% [markdown]
# Utworzymy teraz nowe wystąpienie modelu z klasy MyModel(), które możemy trenować za pomocą
# danych uczących.
#
# Wymiarowość danych wejściowych (liczbę cech, równą w tym przypadku 1 - jedna waga w - obciążenie nie jest liczone do wymiaru) tego modelu zdefiniowano jawnie w konstruktorze.
#
# Można to jednak zrobić przez metodę model.build() - nazywany jest późnym tworzeniem
# zmiennych (ang. late variable creation). Metoda ta specyfikuje znany już z modelu Sequential parametr input_shape.

# %%
model = MyModel()

model.build(input_shape=(None, 1))
model.summary()
plot_model(model, to_file='model_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Istotne jest zwrócenie uwagi, że w miejsce pierwszego wymiaru oczekiwanych danych wejściowych input_shape wstawiono
# wartość None, dzięki czemu możemy wyznaczyć dowolny
# rozmiar grupy. Jednak liczba cech jest stała (w tym przypadku 1), ponieważ wiąże się ona
# bezpośrednio z liczbą wag modelu.
#
# #### 5.1.4. Zdefiniowanie funkcji straty i metody optymalizacji
#
# W tym przypadku jako funkcję straty wybieramy błąd średniokwadratowy (MSE). Ponadto do określenia wag modelu wykorzystamy algorytm stochastycznego spadku wzdłuż gradientu. Zaimplementujemy go tutaj własnoręcznie (wykorzystując tf.GradientTape), chociaż można by użyć znane już funkcje compile() i fit().

# %%
# funkcja straty

def loss_fn(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))


## testowanie funkcji:
yt = tf.convert_to_tensor([1.0])
yp = tf.convert_to_tensor([1.5])

loss_fn(yt, yp)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.25>

# %%
# algorytm optymalizacji - proces uczenia

def train(model, inputs, outputs, learning_rate):
    with tf.GradientTape() as tape:
        current_loss = loss_fn(model(inputs), outputs)
    dW, db = tape.gradient(current_loss, [model.w, model.b])
    model.w.assign_sub(learning_rate * dW)
    model.b.assign_sub(learning_rate * db)

# %% [markdown]
# #### 5.1.5. Uruchomienie modelu
#
# Możemy teraz wyznaczyć hiperparametry i wyuczyć model przez 200 epok. Stworzymy wersję wsadową zestawu danych i powtórzymy go z wartością count=None (ds_train.repeat(count=None)), co oznacza, że będzie on powtarzany
# w nieskończoność. Kluczowa  pętla jest bardzo podobna koncepcyjnie do kodu implementacji MLP.

# %%
tf.random.set_seed(1)

num_epochs = 200
log_steps = 100
learning_rate = 0.001
batch_size = 1
steps_per_epoch = int(np.ceil(len(y_train) / batch_size))


ds_train = ds_train_orig.shuffle(buffer_size=len(y_train))
ds_train = ds_train.repeat(count=None)
ds_train = ds_train.batch(1)

Ws, bs = [], []

for i, batch in enumerate(ds_train):
    if i >= steps_per_epoch * num_epochs:
        break
    Ws.append(model.w.numpy())
    bs.append(model.b.numpy())

    bx, by = batch
    loss_val = loss_fn(model(bx), by)

    train(model, bx, by, learning_rate=learning_rate)
    if i%log_steps==0:
        print('Epoka numer {:4d} Krok numer  {:2d} Funkcja straty {:6.4f}'.format(
              int(i/steps_per_epoch), i, loss_val))
# Out:
# Epoka numer    0 Krok numer   0 Funkcja straty 43.5600
# Epoka numer   10 Krok numer  100 Funkcja straty 0.7530
# Epoka numer   20 Krok numer  200 Funkcja straty 20.1759
# Epoka numer   30 Krok numer  300 Funkcja straty 23.3976
# Epoka numer   40 Krok numer  400 Funkcja straty 6.3481
# Epoka numer   50 Krok numer  500 Funkcja straty 4.6356
# Epoka numer   60 Krok numer  600 Funkcja straty 0.2411
# Epoka numer   70 Krok numer  700 Funkcja straty 0.2036
# Epoka numer   80 Krok numer  800 Funkcja straty 3.8177
# Epoka numer   90 Krok numer  900 Funkcja straty 0.9416
# Epoka numer  100 Krok numer  1000 Funkcja straty 0.7035
# Epoka numer  110 Krok numer  1100 Funkcja straty 0.0348
# Epoka numer  120 Krok numer  1200 Funkcja straty 0.5404
# Epoka numer  130 Krok numer  1300 Funkcja straty 0.1170
# Epoka numer  140 Krok numer  1400 Funkcja straty 0.1195
# Epoka numer  150 Krok numer  1500 Funkcja straty 0.0944
# Epoka numer  160 Krok numer  1600 Funkcja straty 0.4670
# Epoka numer  170 Krok numer  1700 Funkcja straty 2.0695
# Epoka numer  180 Krok numer  1800 Funkcja straty 0.0020
# Epoka numer  190 Krok numer  1900 Funkcja straty 0.3612

# %% [markdown]
# #### 5.1.6. Test modelu
#
# Jako dane testowe stworzymy tablicę NumPy zawierającą wartości równomiernie rozmieszczone w przedziale
# od 0 do 9. Wyuczyliśmy model na standaryzowanych cechach, dlatego przeprowadzimy taką samą
# standaryzację danych testowych:

# %%
print('Parametry końcowe:', model.w.numpy(), model.b.numpy())

X_test = np.linspace(0, 9, num=100).reshape(-1, 1)
X_test_norm = (X_test - np.mean(X_train)) / np.std(X_train)

y_pred = model(tf.cast(X_test_norm, dtype=tf.float32))
# Out:
# Parametry końcowe: 2.6576622 4.8798566

# %% [markdown]
# #### 5.1.7. Wizualizacja wyników
#
# Rysunki pokazują wykres punktowy przykładów uczących i wyuczonego modelu
# regresji liniowej, a także wykres historii zbieżności wagi w i obciążenia jednostkowego b.

# %%
fig = plt.figure(figsize=(13, 5))
ax = fig.add_subplot(1, 2, 1)
plt.plot(X_train_norm, y_train, 'o', markersize=10)
plt.plot(X_test_norm, y_pred, '--', lw=3)
plt.legend(['Przykłady uczące', 'Reg. liniowa'], fontsize=15)
ax.set_xlabel('x', size=15)
ax.set_ylabel('y', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
plt.plot(Ws, lw=3)
plt.plot(bs, lw=3)
plt.legend(['Waga w', 'Obc. jednostkowe b'], fontsize=15)
ax.set_xlabel('Iteracja', size=15)
ax.set_ylabel('Wartość', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
#plt.savefig('r13-reglin-1.pdf')

plt.show()

# %% [markdown]
# ### 5.2. Model z kilkoma warstwami - klasyfikacja XOR
#
# Tym razem korzystamy z funkcji compile() oraz fit().

# %%
from mlxtend.plotting import plot_decision_regions

class MyModel(tf.keras.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.hidden_1 = tf.keras.layers.Dense(units=4, activation='relu')
        self.hidden_2 = tf.keras.layers.Dense(units=4, activation='relu')
        self.hidden_3 = tf.keras.layers.Dense(units=4, activation='relu')
        self.output_layer = tf.keras.layers.Dense(units=1, activation='sigmoid')
        
    def call(self, inputs):
        h = self.hidden_1(inputs)
        h = self.hidden_2(h)
        h = self.hidden_3(h)
        return self.output_layer(h)
    
tf.random.set_seed(1)

x = np.random.uniform(low=-1, high=1, size=(200, 2))
y = np.ones(len(x))
y[x[:, 0] * x[:, 1]<0] = 0
x_train = x[:100, :]
y_train = y[:100]
x_valid = x[100:, :]
y_valid = y[100:]

## utworzenie instacji modelu:
model = MyModel()
model.build(input_shape=(None, 2))

model.summary()

## kompilowanie:
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

## uczenie:
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, verbose=0)

## tworzenie wykresu
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['F. straty uczenia', 'F. straty walidacji'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Dokładność (uczenie)', 'Dokładność (walidacja)'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 3)
plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),
                      clf=model)
ax.set_xlabel(r'$x_1$', size=15)
ax.xaxis.set_label_coords(1, -0.025)
ax.set_ylabel(r'$x_2$', size=15)
ax.yaxis.set_label_coords(-0.025, 1)
plt.show()
# Out:
# Model: "my_model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             multiple                  12
# _________________________________________________________________
# dense_22 (Dense)             multiple                  20
# _________________________________________________________________
# dense_23 (Dense)             multiple                  20
# _________________________________________________________________
# dense_24 (Dense)             multiple                  5
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# <ipython-input-123-4006e03c9266>:60: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),

# %% [markdown]
# ## 6. Model Functional
#
# Istotne informacje: https://keras.io/guides/functional_api/
#
# Modele utworzone przez <tt>Sequential API</tt> nie pozwalają na  stworzenie modelu, który:
#
# - współdzieli warstwy
# - posiada  rozgałęzienia
# - posiada  wiele wejść i wyjść
#
# Problemy te rozwiązuje  <tt>Functional API</tt>. Model w tym przypadku realizuje w ogólności topologię [acyklicznego grafu skierowanego](https://pl.wikipedia.org/wiki/Skierowany_graf_acykliczny).
#
# ### 6.1  Tworzenie warstw - dwa przykłady demonstarcyjne
#
# Jak widać poniżej korzystamy tu z rozszerzonej składni konstruktorów warstw - zawsze podajemy nazwę warstwy wejściowej dla kolejnej dodawanej. To oczywiście technicznie umożliwia tworzenie rozgałęzień.  Warstwa startowa musi być utworzona przez funkcję [Input](https://keras.io/api/layers/core_layers/input/).
#
# Oprócz znanych już konstruktorów Dense() i Flatten() wykorzystujemy tu
# konstruktor [Reshape](https://keras.io/api/layers/reshaping_layers/reshape/) tworzący warstwę  z danymi jak
# jej warstwa wejściowa, ale zmieniający  jej shape.
#
# Ponadto uzywamy tu konstruktora łączącego [Concatenate](https://keras.io/api/layers/merging_layers/concatenate/) łączącego warstwy wg ustalonej osi (domyślne '-1' oznacza ostatnią oś tensora). Istotna jest ostatnia linia kodu jawnie wywołująca konstruktor klasy Model z parametrami wskazującymi na pierwszą i ostatnią warstwę modelu.

# %%
input_ = keras.layers.Input(shape=[28, 28])
flatten = keras.layers.Flatten(input_shape=[28, 28])(input_)
hidden1 = keras.layers.Dense(2**14, activation="relu")(flatten)
hidden2 = keras.layers.Dense(512, activation='relu')(hidden1)
hidden3 = keras.layers.Dense(28*28, activation='relu')(hidden2)
reshap = keras.layers.Reshape((28, 28))(hidden3)#zmiana kształtu przed łączeniem
concat_ = keras.layers.Concatenate()([input_, reshap])#łączenie wg drugiej (ostatniej) osi
flatten2 = keras.layers.Flatten(input_shape=[28, 28])(concat_)
output = keras.layers.Dense(10, activation='softmax')(flatten2)
model5 = keras.Model(inputs=[input_], outputs=[output] )

# %%
plot_model(model5, to_file='model5_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True)

# %% [markdown]
# Kolejny przykład pokazuje model z dwoma wejściami i dwoma wyjściami oraz posiadający również rozgałęzienia:

# %%
input_A = keras.layers.Input(shape=[28, 28])
input_B = keras.layers.Input(shape=[28, 28])

flatten = keras.layers.Flatten(input_shape=[28, 28])(input_A)
hidden1 = keras.layers.Dense(2**14, activation="relu")(flatten)
hidden2 = keras.layers.Dense(512, activation='relu')(hidden1)
hidden3 = keras.layers.Dense(28*28, activation='relu')(hidden2)
reshap = keras.layers.Reshape((28, 28))(hidden3)
concat_A = keras.layers.Concatenate()([input_A, reshap])
flatten_A = keras.layers.Flatten(input_shape=[28, 28])(concat_A)
output = keras.layers.Dense(10, activation='softmax')(flatten_A)


concat_B = keras.layers.Concatenate()([input_B, reshap])
flatten_B = keras.layers.Flatten(input_shape=[28, 28])(concat_B)

hidden_B = keras.layers.Dense(512, activation='relu')(flatten_B)
output_2nd = keras.layers.Dense(10, activation='softmax')(hidden_B)
model6 = keras.Model(inputs=[input_A, input_B], outputs=[output, output_2nd])

# %%
plot_model(model6, to_file='model6_plot.png', show_shapes=True,show_dtype=True, show_layer_names=True, expand_nested=True)

# %% [markdown]
# W tym przypadku funkcje compile() oraz fit() mogą otrzymać dane podwójne, np.
#
# model.compile(loss=["sparse_categorical_crossentropy", "sparse_categorical_crossentropy"],
#                      optimizer="sgd", metrics=["accuracy"])
#
# res = model.fit([X_train_A, X_train_B], [y_train_A, y_train_B], epochs=10, validation_split= 0.2 )
#
# Przykład współdzielenia warstw można znaleźć w dokumentacji https://keras.io/guides/functional_api/
#
#
# ### 6.2. Przykład produkcyjny - zagadnienie klasyfikacji XOR

# %%
tf.random.set_seed(1)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=4, input_shape=(2,), activation='relu'))
model.add(tf.keras.layers.Dense(units=4, activation='relu'))
model.add(tf.keras.layers.Dense(units=4, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

model.summary()

## kompilacja:
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

## uczenie:
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, verbose=0)

history = hist.history
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 4)                 12
# _________________________________________________________________
# dense_36 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_37 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['F. straty uczenia', 'F. straty walidacji'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Dokładność (uczenie)', 'Dokładność (walidacja)'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 3)
plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),
                      clf=model)
ax.set_xlabel(r'$x_1$', size=15)
ax.xaxis.set_label_coords(1, -0.025)
ax.set_ylabel(r'$x_2$', size=15)
ax.yaxis.set_label_coords(-0.025, 1)
plt.show()
# Out:
# <ipython-input-129-be430ba32df6>:15: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),

# %% [markdown]
# ## 7. Tworzenie niestandardowych warstw Keras
#
# #### Definiowanie niestandardowej warstwy:
#  * Zdefiniuj metodę `__init__()`
#  * Zdefiniuj metodę `build()` w celu późnego tworzenia zmiennych
#  * Zdefiniuj metodę `call()`
#  * Zdefiniuj metodę `get_config()` w celu serializacji
#
# W sytuacjach, gdy musimy zdefiniować nową, niedostępną w interfejsie Keras warstwę, możemy
# wyznaczyć nową klasę wywodzącą się z klasy `tf.keras.layers.Layer`. Przydaje się to
# zwłaszcza podczas projektowania nowej warstwy lub modyfikowania już istniejącej.
#
# Proces implementowania niestandardowych warstw zaprezentujemy na prostym przykładzie.
# Wyobraź sobie, że chcemy zdefiniować nową warstwę liniową, obliczającą operację
# $w(x+\varepsilon)+b$ , gdzie $\varepsilon$ odnosi się do zmiennej losowej odzwierciedlającej szum.
#
# W celu
# zaimplementowania tej operacji zdefiniujemy nową podklasę klasy `tf.keras.layers.Layer`.
# Przygotujemy zarówno metodę `__init__()` konstruktora, jak również metodę `call()`. W konstruktorze
# zdefiniujemy zmienne i inne tensory wymagane w niestandardowej warstwie.
#
# Mamy możliwość tworzenia zmiennych i inicjalizowania ich w konstruktorze, jeżeli przekażemy
# do niego `input_shape`. Ewentualnie możemy opóźnić inicjalizację zmiennej (na przykład
# jeśli nie znamy jeszcze rozmiaru danych wejściowych) i delegować ją do metody `build()` w celu
# późnego tworzenia zmiennych.
#
# Dodatkowo możemy wprowadzić serializację za pomocą
# metody `get_config()`, co oznacza, że model wykorzystujący niestandardową warstwę będzie
# skutecznie zapisywany za pomocą możliwości zapisu i odczytu TensorFlow.
#
# W ramach przykładu zdefiniujemy nową warstwę o nazwie NoisyLinear, obliczającą wspomnianą
# już operację $w(x+\varepsilon)+b$:

# %%
class NoisyLinear(tf.keras.layers.Layer):
    def __init__(self, output_dim, noise_stddev=0.1, **kwargs):
        self.output_dim = output_dim
        self.noise_stddev = noise_stddev
        super(NoisyLinear, self).__init__(**kwargs)

    def build(self, input_shape):
        self.w = self.add_weight(name='wagi',
                                 shape=(input_shape[1], self.output_dim),
                                 initializer='random_normal',
                                 trainable=True)
        
        self.b = self.add_weight(shape=(self.output_dim,),
                                 initializer='zeros',
                                 trainable=True)

    def call(self, inputs, training=False):
        if training:
            batch = tf.shape(inputs)[0]
            dim = tf.shape(inputs)[1]
            noise = tf.random.normal(shape=(batch, dim),
                                     mean=0.0,
                                     stddev=self.noise_stddev)

            noisy_inputs = tf.add(inputs, noise)
        else:
            noisy_inputs = inputs
        z = tf.matmul(noisy_inputs, self.w) + self.b
        return tf.keras.activations.relu(z)
    
    def get_config(self):
        config = super(NoisyLinear, self).get_config()
        config.update({'output_dim': self.output_dim,
                       'noise_stddev': self.noise_stddev})
        return config


## testowanie:

tf.random.set_seed(1)

noisy_layer = NoisyLinear(4)
noisy_layer.build(input_shape=(None, 4))

x = tf.zeros(shape=(1, 4))
tf.print(noisy_layer(x, training=True))

## odtwarzanie z obiektu config:
config = noisy_layer.get_config()
new_layer = NoisyLinear.from_config(config)
tf.print(new_layer(x, training=True))
# Out:
# [[0 0.00821428 0 0]]
# [[0 0.0108502861 0 0]]

# %% [markdown]
# Dodaliśmy w konstruktorze argument noise_stddev określający odchylenie standardowe rozkładu
# $\varepsilon$ , bazującego na rozkładzie gaussowskim.
#
# Ponadto zwróć uwagę, że w metodzie `call()`
# użyliśmy dodatkowego argumentu: `training=False`. W kontekście interfejsu Keras argument
# logiczny training ma specjalne znaczenie; za jego pomocą decydujemy, czy dany model (lub
# warstwa) jest używany w fazie uczenia (np. poprzez metodę `fit()`), czy tylko do przewidywania
# (np. poprzez metodę `predict()`; czasami etap ten jest nazywany „wnioskowaniem” lub
# ewaluacją).
#
# Jedną z zasadniczych różnic pomiędzy uczeniem a przewidywaniem jest ignorowanie
# gradientów w czasie predykcji. Istnieją także pewne metody, które działają inaczej
# w fazie uczenia i przewidywania, np. porzucanie (Dropout).
#
# W powyższym listingu określiliśmy także, że wektor szumu $\varepsilon$ będzie
# generowany i dodawany do danych wejściowych jedynie w trakcie uczenia, czyli nie będziemy
# korzystać z niego w fazie wnioskowania.
#
# Zanim przejdziemy dalej, skorzystamy z warstwy `NoisyLinear` w modelu, przetestujmy ją na
# prostym przykładzie.

# %%
tf.random.set_seed(1)

model = tf.keras.Sequential([
    NoisyLinear(4, noise_stddev=0.1),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')])

model.build(input_shape=(None, 2))
model.summary()

## kompilacja:
model.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

## uczenie:
hist = model.fit(x_train, y_train, 
                 validation_data=(x_valid, y_valid), 
                 epochs=200, batch_size=2, 
                 verbose=0)

## tworzenie wykresu
history = hist.history

fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 3, 1)
plt.plot(history['loss'], lw=4)
plt.plot(history['val_loss'], lw=4)
plt.legend(['F. straty uczenia', 'F. straty walidacji'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 2)
plt.plot(history['binary_accuracy'], lw=4)
plt.plot(history['val_binary_accuracy'], lw=4)
plt.legend(['Dokładność (uczenie)', 'Dokładność (walidacja)'], fontsize=15)
ax.set_xlabel('Epoki', size=15)

ax = fig.add_subplot(1, 3, 3)
plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),
                      clf=model)
ax.set_xlabel(r'$x_1$', size=15)
ax.xaxis.set_label_coords(1, -0.025)
ax.set_ylabel(r'$x_2$', size=15)
ax.yaxis.set_label_coords(-0.025, 1)
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method NoisyLinear.call of <__main__.NoisyLinear object at 0x00000195C41EBCD0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method NoisyLinear.call of <__main__.NoisyLinear object at 0x00000195C41EBCD0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method NoisyLinear.call of <__main__.NoisyLinear object at 0x00000195C41EBCD0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# noisy_linear_1 (NoisyLinear) (None, 4)                 12
# _________________________________________________________________
# dense_39 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_40 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________
# <ipython-input-131-3fe2af7f3de2>:40: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X=x_valid, y=y_valid.astype(np.integer),

# %% [markdown]
# ## 8. Estymatory
#
# Interfejs `tf.estimator` zawiera mechanizmy zadań uczenia maszynowego, takie
# jak uczenie, przewidywanie (wnioskowanie) i ocena. Estymatory są bardziej hermetyczne,
# ale jednocześnie skalowalne w porównaniu z wcześniej omówionymi technikami. Ponadto
# interfejs `tf.estimator`dodaje obsługę realizowania modeli na wielu różnych platformach
# bez konieczności wprowadzania znacznych modyfikacji kodu, przez co przydaje się on
# w tzw. „fazie produkcyjnej” w zastosowaniach przemysłowych. To nie wszystko, gdyż moduł
# TensorFlow zawiera asortyment gotowych estymatorów przeznaczonych do struktur uczenia
# maszynowego i uczenia głębokiego, które przydają się w badaniach porównawczych, np. w celu
# szybkiej oceny, czy dana technika nadaje się do określonego zestawu danych lub problemu

# %%
tf.random.set_seed(1)
np.random.seed(1)

# %% [markdown]
# ### Praca z kolumnami cech
#
#
#  * Definicja: https://developers.google.com/machine-learning/glossary/#feature_columns
#  * Dokumentacja: https://www.tensorflow.org/api_docs/python/tf/feature_column

# %%
Image(filename='rysunki/02.png', width=700)

# %% [markdown]
# Widoczne na  rysunku cechy (rocznik modelu, cylindry, pojemność skokowa, moc silnika,
# waga, przyspieszenie i obszar pochodzenia) pochodzą z popularnego, wzorcowego zestawu
# danych Auto MPG, przewidującego spalanie w milach na galon (MPG). Pełny zestaw danych
# wraz z opisem jest dostępny w repozytorium uczenia maszynowego UCI na stronie
# http://archive.ics.uci.edu/ml/datasets/Auto+MPG.
# Będziemy traktować pięć cech z zestawu danych Auto MPG (liczbę cylindrów, pojemność
# skokową, moc silnika, wagę i przyspieszenie) jako cechy „numeryczne” (tutaj ciągłe). Rocznik
# modelu można uznać za uporządkowaną cechę kategorialną (porządkową). Z kolei obszarpochodzenia będzie naszą nieuporządkowaną cechą kategorialną (nominalną), przyjmującą
# trzy możliwe wartości dyskretne: 1, 2 i 3, odpowiadające, kolejno, Stanom Zjednoczonym,
# Europie i Japonii.
# Wczytajmy najpierw dane i wykonajmy niezbędne operacje przetwarzania wstępnego, takie
# jak podzielenie zestawu danych na zbiory uczący i testowy, a także standaryzowanie cech
# ciągłych:

# %%
dataset_path = tf.keras.utils.get_file("auto-mpg.data", 
                                       ("http://archive.ics.uci.edu/ml/machine-learning-databases"
                                        "/auto-mpg/auto-mpg.data"))

column_names = ['Spalanie', 'Cylindry', 'Poj_skokowa', 'Moc',
                'Waga', 'Przyspieszenie', 'Rocznik_modelu', 'Obszar_pochodzenia']

df = pd.read_csv(dataset_path, names=column_names,
                 na_values = "?", comment='\t',
                 sep=" ", skipinitialspace=True)

df.tail()
# Out:
#      Spalanie  Cylindry  Poj_skokowa   Moc    Waga  Przyspieszenie  \
# 393      27.0         4        140.0  86.0  2790.0            15.6
# 394      44.0         4         97.0  52.0  2130.0            24.6
# 395      32.0         4        135.0  84.0  2295.0            11.6
# 396      28.0         4        120.0  79.0  2625.0            18.6
# 397      31.0         4        119.0  82.0  2720.0            19.4
#
#      Rocznik_modelu  Obszar_pochodzenia
# 393              82                   1
# 394              82                   2
# 395              82                   1
# 396              82                   1
# 397              82                   1

# %%
print(df.isna().sum())

df = df.dropna()
df = df.reset_index(drop=True)
df.tail()
# Out:
# Spalanie              0
# Cylindry              0
# Poj_skokowa           0
# Moc                   6
# Waga                  0
# Przyspieszenie        0
# Rocznik_modelu        0
# Obszar_pochodzenia    0
# dtype: int64
#      Spalanie  Cylindry  Poj_skokowa   Moc    Waga  Przyspieszenie  \
# 387      27.0         4        140.0  86.0  2790.0            15.6
# 388      44.0         4         97.0  52.0  2130.0            24.6
# 389      32.0         4        135.0  84.0  2295.0            11.6
# 390      28.0         4        120.0  79.0  2625.0            18.6
# 391      31.0         4        119.0  82.0  2720.0            19.4
#
#      Rocznik_modelu  Obszar_pochodzenia
# 387              82                   1
# 388              82                   2
# 389              82                   1
# 390              82                   1
# 391              82                   1

# %%
import sklearn
import sklearn.model_selection


df_train, df_test = sklearn.model_selection.train_test_split(df, train_size=0.8)
train_stats = df_train.describe().transpose()
train_stats
# Out:
#                     count         mean         std     min     25%     50%  \
# Spalanie            313.0    23.484665    7.679557     9.0    17.5    23.0
# Cylindry            313.0     5.453674    1.703671     3.0     4.0     4.0
# Poj_skokowa         313.0   193.557508  104.751063    68.0   104.0   146.0
# Moc                 313.0   104.584665   38.113444    46.0    78.0    94.0
# Waga                313.0  2978.696486  848.340409  1649.0  2255.0  2790.0
# Przyspieszenie      313.0    15.529393    2.712477     8.0    13.7    15.5
# Rocznik_modelu      313.0    76.006390    3.708958    70.0    73.0    76.0
# Obszar_pochodzenia  313.0     1.597444    0.811136     1.0     1.0     1.0
#
#                        75%     max
# Spalanie              29.0    46.6
# Cylindry               8.0     8.0
# Poj_skokowa          262.0   455.0
# Moc                  125.0   230.0
# Waga                3620.0  5140.0
# Przyspieszenie        17.0    24.6
# Rocznik_modelu        79.0    82.0
# Obszar_pochodzenia     2.0     3.0

# %%
numeric_column_names = ['Cylindry', 'Poj_skokowa', 'Moc', 'Waga', 'Przyspieszenie']

df_train_norm, df_test_norm = df_train.copy(), df_test.copy()

for col_name in numeric_column_names:
    mean = train_stats.loc[col_name, 'mean']
    std  = train_stats.loc[col_name, 'std']
    df_train_norm.loc[:, col_name] = (df_train_norm.loc[:, col_name] - mean)/std
    df_test_norm.loc[:, col_name] = (df_test_norm.loc[:, col_name] - mean)/std
    
df_train_norm.tail()
# Out:
#      Spalanie  Cylindry  Poj_skokowa       Moc      Waga  Przyspieszenie  \
# 306      33.5 -0.853260    -0.406273 -0.382665 -0.498263       -0.858770
# 377      38.0 -0.853260    -0.979059 -0.986126 -1.194917       -0.195170
# 222      15.0  1.494611     1.035240  0.666834  1.551622       -0.232036
# 102      11.0  1.494611     1.970791  1.191583  2.379120       -0.563836
# 52       31.0 -0.853260    -1.169988 -1.038601 -1.421241        1.279497
#
#      Rocznik_modelu  Obszar_pochodzenia
# 306              79                   1
# 377              82                   3
# 222              77                   1
# 102              73                   1
# 52               71                   3

# %% [markdown]
# #### Kolumny numeryczne
#
# Stworzony w powyższym listingu obiekt DataFrame zawiera pięć kolumn przechowujących
# wartości typu float. Kolumny te reprezentują cechy ciągłe. W poniższym listingu użyjemy
# funkcji feature_column do przekształcenia tych cech ciągłych w strukturę kolumn cech zrozumiałą
# dla estymatorów TensorFlow:

# %%
numeric_features = []

for col_name in numeric_column_names:
    numeric_features.append(tf.feature_column.numeric_column(key=col_name))
    
numeric_features
# Out:
# [NumericColumn(key='Cylindry', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Poj_skokowa', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Moc', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Waga', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Przyspieszenie', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# Pogrupujmy szczegółowe informacje o rocznikach w przedziały, co ułatwi proces uczenia
# modelu. Mianowicie przypiszemy każdy samochód do jednego z czterech przedziałów
# zgodnie z następującym wzorem:
# $$
# przedział =\left\{
# \begin{array}{ll}
# 0 & \hbox{jeśli rok} < 73\\
# 1 & \hbox{jeśli rok}  73 \leq  76\\
# 2 & \hbox{jeśli rok} 76 \leq  79\\
# 3 & \hbox{jeśli rok} \geq 79
# \end{array}
# \right.
# $$
# Zwróć uwagę, że przedziały zostały wybrane dowolnie w celu zademonstrowania procesu
# grupowania zmiennych. Aby pogrupować dane w te przedziały, musimy najpierw zdefiniować
# cechę numeryczną na podstawie pierwotnego roku wypuszczenia modelu. Następnie te
# cechy numeryczne zostaną przekazane do funkcji bucketized_column, dlatego wyznaczymy
# trzy wartości progowe przedziałów: [73, 76, 79]. Wartości te wyznaczają prawą granicę przedziału.
# W ten sposób można tworzyć przedziały półzamknięte, np. (−, 73], [73, 76), [76, 79) i [79, ).
# Kod wygląda następująco:

# %%
feature_year = tf.feature_column.numeric_column(key="Rocznik_modelu")

bucketized_features = []

bucketized_features.append(tf.feature_column.bucketized_column(
    source_column=feature_year,
    boundaries=[73, 76, 79]))

print(bucketized_features)
# Out:
# [BucketizedColumn(source_column=NumericColumn(key='Rocznik_modelu', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(73, 76, 79))]

# %%
feature_origin = tf.feature_column.categorical_column_with_vocabulary_list(
    key='Obszar_pochodzenia',
    vocabulary_list=[1, 2, 3])

categorical_indicator_features = []
categorical_indicator_features.append(tf.feature_column.indicator_column(feature_origin))

print(categorical_indicator_features)
# Out:
# [IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='Obszar_pochodzenia', vocabulary_list=(1, 2, 3), dtype=tf.int32, default_value=-1, num_oov_buckets=0))]

# %% [markdown]
# ### Uczenie maszynowe za pomocą gotowych estymatorów

# %%
def train_input_fn(df_train, batch_size=8):
    df = df_train.copy()
    train_x, train_y = df, df.pop('Spalanie')
    dataset = tf.data.Dataset.from_tensor_slices((dict(train_x), train_y))

    # tasuje, powtarza i tworzy grupy przykładów
    return dataset.shuffle(1000).repeat().batch(batch_size)

## sprawdzenie
ds = train_input_fn(df_train_norm)
batch = next(iter(ds))
print('Klucze:', batch[0].keys())
print('Grupa (Rocznik_modelu):', batch[0]['Rocznik_modelu'])
# Out:
# Klucze: dict_keys(['Cylindry', 'Poj_skokowa', 'Moc', 'Waga', 'Przyspieszenie', 'Rocznik_modelu', 'Obszar_pochodzenia'])
# Grupa (Rocznik_modelu): tf.Tensor([82 78 76 72 78 73 70 78], shape=(8,), dtype=int64)

# %%
all_feature_columns = (numeric_features + 
                       bucketized_features + 
                       categorical_indicator_features)

print(all_feature_columns)
# Out:
# [NumericColumn(key='Cylindry', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Poj_skokowa', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Moc', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Waga', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Przyspieszenie', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), BucketizedColumn(source_column=NumericColumn(key='Rocznik_modelu', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(73, 76, 79)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='Obszar_pochodzenia', vocabulary_list=(1, 2, 3), dtype=tf.int32, default_value=-1, num_oov_buckets=0))]

# %%
regressor = tf.estimator.DNNRegressor(
    feature_columns=all_feature_columns,
    hidden_units=[32, 10],
    model_dir='modele/autompg-dnnregresor/')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'modele/autompg-dnnregresor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': 'modele/autompg-dnnregresor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
EPOCHS = 1000
BATCH_SIZE = 8
total_steps = EPOCHS * int(np.ceil(len(df_train) / BATCH_SIZE))
print('Kroki uczenia:', total_steps)

regressor.train(
    input_fn=lambda:train_input_fn(df_train_norm, batch_size=BATCH_SIZE),
    steps=total_steps)
# Out:
# Kroki uczenia: 40000
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:AutoGraph could not transform <bound method _DNNModelV2.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModelV2 object at 0x00000195FBCA8910>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method _DNNModelV2.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModelV2 object at 0x00000195FBCA8910>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method _DNNModelV2.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModelV2 object at 0x00000195FBCA8910>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\optimizer_v2\adagrad.py:82: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\optimizer_v2\adagrad.py:82: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into modele/autompg-dnnregresor/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 0 into modele/autompg-dnnregresor/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 611.7914, step = 0
# INFO:tensorflow:loss = 611.7914, step = 0
# INFO:tensorflow:global_step/sec: 783.374
# INFO:tensorflow:global_step/sec: 783.374
# INFO:tensorflow:loss = 447.156, step = 100 (0.130 sec)
# INFO:tensorflow:loss = 447.156, step = 100 (0.130 sec)
# INFO:tensorflow:global_step/sec: 1086.95
# INFO:tensorflow:global_step/sec: 1086.95
# INFO:tensorflow:loss = 740.2078, step = 200 (0.090 sec)
# INFO:tensorflow:loss = 740.2078, step = 200 (0.090 sec)
# INFO:tensorflow:global_step/sec: 1158.74
# INFO:tensorflow:global_step/sec: 1158.74
# INFO:tensorflow:loss = 569.8496, step = 300 (0.087 sec)
# INFO:tensorflow:loss = 569.8496, step = 300 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1144.57
# INFO:tensorflow:global_step/sec: 1144.57
# INFO:tensorflow:loss = 668.36743, step = 400 (0.087 sec)
# INFO:tensorflow:loss = 668.36743, step = 400 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1183.26
# INFO:tensorflow:global_step/sec: 1183.26
# INFO:tensorflow:loss = 628.1408, step = 500 (0.085 sec)
# INFO:tensorflow:loss = 628.1408, step = 500 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1133.3
# INFO:tensorflow:global_step/sec: 1133.3
# INFO:tensorflow:loss = 586.4225, step = 600 (0.088 sec)
# INFO:tensorflow:loss = 586.4225, step = 600 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1137.49
# INFO:tensorflow:global_step/sec: 1137.49
# INFO:tensorflow:loss = 672.6925, step = 700 (0.088 sec)
# INFO:tensorflow:loss = 672.6925, step = 700 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1159.83
# INFO:tensorflow:global_step/sec: 1159.83
# INFO:tensorflow:loss = 669.073, step = 800 (0.085 sec)
# INFO:tensorflow:loss = 669.073, step = 800 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1232
# INFO:tensorflow:global_step/sec: 1232
# INFO:tensorflow:loss = 657.9373, step = 900 (0.082 sec)
# INFO:tensorflow:loss = 657.9373, step = 900 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1237.36
# INFO:tensorflow:global_step/sec: 1237.36
# INFO:tensorflow:loss = 401.7555, step = 1000 (0.081 sec)
# INFO:tensorflow:loss = 401.7555, step = 1000 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1247.09
# INFO:tensorflow:global_step/sec: 1247.09
# INFO:tensorflow:loss = 364.70792, step = 1100 (0.079 sec)
# INFO:tensorflow:loss = 364.70792, step = 1100 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1169.92
# INFO:tensorflow:global_step/sec: 1169.92
# INFO:tensorflow:loss = 591.6242, step = 1200 (0.086 sec)
# INFO:tensorflow:loss = 591.6242, step = 1200 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1163.09
# INFO:tensorflow:global_step/sec: 1163.09
# INFO:tensorflow:loss = 738.2726, step = 1300 (0.086 sec)
# INFO:tensorflow:loss = 738.2726, step = 1300 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1234.56
# INFO:tensorflow:global_step/sec: 1234.56
# INFO:tensorflow:loss = 473.5677, step = 1400 (0.082 sec)
# INFO:tensorflow:loss = 473.5677, step = 1400 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1176.47
# INFO:tensorflow:global_step/sec: 1176.47
# INFO:tensorflow:loss = 633.5463, step = 1500 (0.084 sec)
# INFO:tensorflow:loss = 633.5463, step = 1500 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1249.99
# INFO:tensorflow:global_step/sec: 1249.99
# INFO:tensorflow:loss = 518.8053, step = 1600 (0.080 sec)
# INFO:tensorflow:loss = 518.8053, step = 1600 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1162.78
# INFO:tensorflow:global_step/sec: 1162.78
# INFO:tensorflow:loss = 501.372, step = 1700 (0.086 sec)
# INFO:tensorflow:loss = 501.372, step = 1700 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1075.3
# INFO:tensorflow:global_step/sec: 1075.3
# INFO:tensorflow:loss = 477.66846, step = 1800 (0.093 sec)
# INFO:tensorflow:loss = 477.66846, step = 1800 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1136.03
# INFO:tensorflow:global_step/sec: 1136.03
# INFO:tensorflow:loss = 417.9715, step = 1900 (0.088 sec)
# INFO:tensorflow:loss = 417.9715, step = 1900 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1316.16
# INFO:tensorflow:global_step/sec: 1316.16
# INFO:tensorflow:loss = 511.76395, step = 2000 (0.075 sec)
# INFO:tensorflow:loss = 511.76395, step = 2000 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1282.05
# INFO:tensorflow:global_step/sec: 1282.05
# INFO:tensorflow:loss = 554.34375, step = 2100 (0.079 sec)
# INFO:tensorflow:loss = 554.34375, step = 2100 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1267.42
# INFO:tensorflow:global_step/sec: 1267.42
# INFO:tensorflow:loss = 559.13635, step = 2200 (0.078 sec)
# INFO:tensorflow:loss = 559.13635, step = 2200 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1259.8
# INFO:tensorflow:global_step/sec: 1259.8
# INFO:tensorflow:loss = 354.76062, step = 2300 (0.080 sec)
# INFO:tensorflow:loss = 354.76062, step = 2300 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1201.59
# INFO:tensorflow:global_step/sec: 1201.59
# INFO:tensorflow:loss = 621.181, step = 2400 (0.082 sec)
# INFO:tensorflow:loss = 621.181, step = 2400 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1225.64
# INFO:tensorflow:global_step/sec: 1225.64
# INFO:tensorflow:loss = 486.1913, step = 2500 (0.084 sec)
# INFO:tensorflow:loss = 486.1913, step = 2500 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1162.96
# INFO:tensorflow:global_step/sec: 1162.96
# INFO:tensorflow:loss = 734.389, step = 2600 (0.084 sec)
# INFO:tensorflow:loss = 734.389, step = 2600 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1183.13
# INFO:tensorflow:global_step/sec: 1183.13
# INFO:tensorflow:loss = 633.6511, step = 2700 (0.087 sec)
# INFO:tensorflow:loss = 633.6511, step = 2700 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1150.2
# INFO:tensorflow:global_step/sec: 1150.2
# INFO:tensorflow:loss = 489.3061, step = 2800 (0.086 sec)
# INFO:tensorflow:loss = 489.3061, step = 2800 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1193.34
# INFO:tensorflow:global_step/sec: 1193.34
# INFO:tensorflow:loss = 576.06964, step = 2900 (0.084 sec)
# INFO:tensorflow:loss = 576.06964, step = 2900 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1182.86
# INFO:tensorflow:global_step/sec: 1182.86
# INFO:tensorflow:loss = 511.82025, step = 3000 (0.085 sec)
# INFO:tensorflow:loss = 511.82025, step = 3000 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1169.12
# INFO:tensorflow:global_step/sec: 1169.12
# INFO:tensorflow:loss = 434.28043, step = 3100 (0.086 sec)
# INFO:tensorflow:loss = 434.28043, step = 3100 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1110.91
# INFO:tensorflow:global_step/sec: 1110.91
# INFO:tensorflow:loss = 817.53467, step = 3200 (0.090 sec)
# INFO:tensorflow:loss = 817.53467, step = 3200 (0.090 sec)
# INFO:tensorflow:global_step/sec: 1219.68
# INFO:tensorflow:global_step/sec: 1219.68
# INFO:tensorflow:loss = 518.02704, step = 3300 (0.082 sec)
# INFO:tensorflow:loss = 518.02704, step = 3300 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1176.53
# INFO:tensorflow:global_step/sec: 1176.53
# INFO:tensorflow:loss = 462.38522, step = 3400 (0.085 sec)
# INFO:tensorflow:loss = 462.38522, step = 3400 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1204.56
# INFO:tensorflow:global_step/sec: 1204.56
# INFO:tensorflow:loss = 532.34985, step = 3500 (0.083 sec)
# INFO:tensorflow:loss = 532.34985, step = 3500 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1219.76
# INFO:tensorflow:global_step/sec: 1219.76
# INFO:tensorflow:loss = 526.8373, step = 3600 (0.081 sec)
# INFO:tensorflow:loss = 526.8373, step = 3600 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1388.89
# INFO:tensorflow:global_step/sec: 1388.89
# INFO:tensorflow:loss = 334.79028, step = 3700 (0.073 sec)
# INFO:tensorflow:loss = 334.79028, step = 3700 (0.073 sec)
# INFO:tensorflow:global_step/sec: 1282.08
# INFO:tensorflow:global_step/sec: 1282.08
# INFO:tensorflow:loss = 300.11578, step = 3800 (0.077 sec)
# INFO:tensorflow:loss = 300.11578, step = 3800 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1282.04
# INFO:tensorflow:global_step/sec: 1282.04
# INFO:tensorflow:loss = 502.19202, step = 3900 (0.079 sec)
# INFO:tensorflow:loss = 502.19202, step = 3900 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1086.17
# INFO:tensorflow:global_step/sec: 1086.17
# INFO:tensorflow:loss = 577.3347, step = 4000 (0.093 sec)
# INFO:tensorflow:loss = 577.3347, step = 4000 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1192.54
# INFO:tensorflow:global_step/sec: 1192.54
# INFO:tensorflow:loss = 580.7052, step = 4100 (0.083 sec)
# INFO:tensorflow:loss = 580.7052, step = 4100 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1209.27
# INFO:tensorflow:global_step/sec: 1209.27
# INFO:tensorflow:loss = 709.1035, step = 4200 (0.082 sec)
# INFO:tensorflow:loss = 709.1035, step = 4200 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1155.6
# INFO:tensorflow:global_step/sec: 1155.6
# INFO:tensorflow:loss = 464.43658, step = 4300 (0.088 sec)
# INFO:tensorflow:loss = 464.43658, step = 4300 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1090.94
# INFO:tensorflow:global_step/sec: 1090.94
# INFO:tensorflow:loss = 404.2855, step = 4400 (0.092 sec)
# INFO:tensorflow:loss = 404.2855, step = 4400 (0.092 sec)
# INFO:tensorflow:global_step/sec: 1197.3
# INFO:tensorflow:global_step/sec: 1197.3
# INFO:tensorflow:loss = 384.04895, step = 4500 (0.083 sec)
# INFO:tensorflow:loss = 384.04895, step = 4500 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1210.19
# INFO:tensorflow:global_step/sec: 1210.19
# INFO:tensorflow:loss = 460.20624, step = 4600 (0.083 sec)
# INFO:tensorflow:loss = 460.20624, step = 4600 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:loss = 624.0104, step = 4700 (0.076 sec)
# INFO:tensorflow:loss = 624.0104, step = 4700 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1293.78
# INFO:tensorflow:global_step/sec: 1293.78
# INFO:tensorflow:loss = 482.05566, step = 4800 (0.077 sec)
# INFO:tensorflow:loss = 482.05566, step = 4800 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1178.73
# INFO:tensorflow:global_step/sec: 1178.73
# INFO:tensorflow:loss = 369.94617, step = 4900 (0.084 sec)
# INFO:tensorflow:loss = 369.94617, step = 4900 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1132.41
# INFO:tensorflow:global_step/sec: 1132.41
# INFO:tensorflow:loss = 573.374, step = 5000 (0.089 sec)
# INFO:tensorflow:loss = 573.374, step = 5000 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1201.26
# INFO:tensorflow:global_step/sec: 1201.26
# INFO:tensorflow:loss = 392.77963, step = 5100 (0.082 sec)
# INFO:tensorflow:loss = 392.77963, step = 5100 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1215.84
# INFO:tensorflow:global_step/sec: 1215.84
# INFO:tensorflow:loss = 347.62848, step = 5200 (0.083 sec)
# INFO:tensorflow:loss = 347.62848, step = 5200 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1086.85
# INFO:tensorflow:global_step/sec: 1086.85
# INFO:tensorflow:loss = 623.7585, step = 5300 (0.091 sec)
# INFO:tensorflow:loss = 623.7585, step = 5300 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1351.37
# INFO:tensorflow:global_step/sec: 1351.37
# INFO:tensorflow:loss = 549.1831, step = 5400 (0.075 sec)
# INFO:tensorflow:loss = 549.1831, step = 5400 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1408.08
# INFO:tensorflow:global_step/sec: 1408.08
# INFO:tensorflow:loss = 384.80713, step = 5500 (0.071 sec)
# INFO:tensorflow:loss = 384.80713, step = 5500 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1286.59
# INFO:tensorflow:global_step/sec: 1286.59
# INFO:tensorflow:loss = 471.35678, step = 5600 (0.078 sec)
# INFO:tensorflow:loss = 471.35678, step = 5600 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1188.31
# INFO:tensorflow:global_step/sec: 1188.31
# INFO:tensorflow:loss = 440.63663, step = 5700 (0.083 sec)
# INFO:tensorflow:loss = 440.63663, step = 5700 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1252.79
# INFO:tensorflow:global_step/sec: 1252.79
# INFO:tensorflow:loss = 590.5471, step = 5800 (0.080 sec)
# INFO:tensorflow:loss = 590.5471, step = 5800 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1250.11
# INFO:tensorflow:global_step/sec: 1250.11
# INFO:tensorflow:loss = 520.90826, step = 5900 (0.080 sec)
# INFO:tensorflow:loss = 520.90826, step = 5900 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1190.49
# INFO:tensorflow:global_step/sec: 1190.49
# INFO:tensorflow:loss = 494.63806, step = 6000 (0.084 sec)
# INFO:tensorflow:loss = 494.63806, step = 6000 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1223.67
# INFO:tensorflow:global_step/sec: 1223.67
# INFO:tensorflow:loss = 591.5078, step = 6100 (0.082 sec)
# INFO:tensorflow:loss = 591.5078, step = 6100 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1190.48
# INFO:tensorflow:global_step/sec: 1190.48
# INFO:tensorflow:loss = 359.615, step = 6200 (0.084 sec)
# INFO:tensorflow:loss = 359.615, step = 6200 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1149.61
# INFO:tensorflow:global_step/sec: 1149.61
# INFO:tensorflow:loss = 331.2544, step = 6300 (0.088 sec)
# INFO:tensorflow:loss = 331.2544, step = 6300 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1208.81
# INFO:tensorflow:global_step/sec: 1208.81
# INFO:tensorflow:loss = 313.3933, step = 6400 (0.082 sec)
# INFO:tensorflow:loss = 313.3933, step = 6400 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1202.1
# INFO:tensorflow:global_step/sec: 1202.1
# INFO:tensorflow:loss = 457.21545, step = 6500 (0.084 sec)
# INFO:tensorflow:loss = 457.21545, step = 6500 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1041.65
# INFO:tensorflow:global_step/sec: 1041.65
# INFO:tensorflow:loss = 382.38065, step = 6600 (0.096 sec)
# INFO:tensorflow:loss = 382.38065, step = 6600 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1190.47
# INFO:tensorflow:global_step/sec: 1190.47
# INFO:tensorflow:loss = 491.85657, step = 6700 (0.083 sec)
# INFO:tensorflow:loss = 491.85657, step = 6700 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1315.85
# INFO:tensorflow:global_step/sec: 1315.85
# INFO:tensorflow:loss = 388.47565, step = 6800 (0.076 sec)
# INFO:tensorflow:loss = 388.47565, step = 6800 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1176.44
# INFO:tensorflow:global_step/sec: 1176.44
# INFO:tensorflow:loss = 345.7365, step = 6900 (0.085 sec)
# INFO:tensorflow:loss = 345.7365, step = 6900 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1369.87
# INFO:tensorflow:global_step/sec: 1369.87
# INFO:tensorflow:loss = 320.20624, step = 7000 (0.074 sec)
# INFO:tensorflow:loss = 320.20624, step = 7000 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1176.49
# INFO:tensorflow:global_step/sec: 1176.49
# INFO:tensorflow:loss = 215.61334, step = 7100 (0.085 sec)
# INFO:tensorflow:loss = 215.61334, step = 7100 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1281.73
# INFO:tensorflow:global_step/sec: 1281.73
# INFO:tensorflow:loss = 436.63684, step = 7200 (0.078 sec)
# INFO:tensorflow:loss = 436.63684, step = 7200 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1316.06
# INFO:tensorflow:global_step/sec: 1316.06
# INFO:tensorflow:loss = 329.24957, step = 7300 (0.075 sec)
# INFO:tensorflow:loss = 329.24957, step = 7300 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1250.06
# INFO:tensorflow:global_step/sec: 1250.06
# INFO:tensorflow:loss = 417.9196, step = 7400 (0.081 sec)
# INFO:tensorflow:loss = 417.9196, step = 7400 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1234.56
# INFO:tensorflow:global_step/sec: 1234.56
# INFO:tensorflow:loss = 478.91174, step = 7500 (0.080 sec)
# INFO:tensorflow:loss = 478.91174, step = 7500 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1219.46
# INFO:tensorflow:global_step/sec: 1219.46
# INFO:tensorflow:loss = 498.5095, step = 7600 (0.083 sec)
# INFO:tensorflow:loss = 498.5095, step = 7600 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1190.53
# INFO:tensorflow:global_step/sec: 1190.53
# INFO:tensorflow:loss = 302.89227, step = 7700 (0.084 sec)
# INFO:tensorflow:loss = 302.89227, step = 7700 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1204.79
# INFO:tensorflow:global_step/sec: 1204.79
# INFO:tensorflow:loss = 341.8485, step = 7800 (0.082 sec)
# INFO:tensorflow:loss = 341.8485, step = 7800 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1136.19
# INFO:tensorflow:global_step/sec: 1136.19
# INFO:tensorflow:loss = 272.201, step = 7900 (0.089 sec)
# INFO:tensorflow:loss = 272.201, step = 7900 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1190.62
# INFO:tensorflow:global_step/sec: 1190.62
# INFO:tensorflow:loss = 467.94458, step = 8000 (0.084 sec)
# INFO:tensorflow:loss = 467.94458, step = 8000 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1111.16
# INFO:tensorflow:global_step/sec: 1111.16
# INFO:tensorflow:loss = 294.77774, step = 8100 (0.091 sec)
# INFO:tensorflow:loss = 294.77774, step = 8100 (0.091 sec)
# INFO:tensorflow:global_step/sec: 1136.32
# INFO:tensorflow:global_step/sec: 1136.32
# INFO:tensorflow:loss = 271.47186, step = 8200 (0.087 sec)
# INFO:tensorflow:loss = 271.47186, step = 8200 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1190.52
# INFO:tensorflow:global_step/sec: 1190.52
# INFO:tensorflow:loss = 267.88953, step = 8300 (0.084 sec)
# INFO:tensorflow:loss = 267.88953, step = 8300 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1315.73
# INFO:tensorflow:global_step/sec: 1315.73
# INFO:tensorflow:loss = 296.07684, step = 8400 (0.076 sec)
# INFO:tensorflow:loss = 296.07684, step = 8400 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1315.77
# INFO:tensorflow:global_step/sec: 1315.77
# INFO:tensorflow:loss = 376.3296, step = 8500 (0.076 sec)
# INFO:tensorflow:loss = 376.3296, step = 8500 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1282.13
# INFO:tensorflow:global_step/sec: 1282.13
# INFO:tensorflow:loss = 307.33032, step = 8600 (0.078 sec)
# INFO:tensorflow:loss = 307.33032, step = 8600 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1298.64
# INFO:tensorflow:global_step/sec: 1298.64
# INFO:tensorflow:loss = 432.97278, step = 8700 (0.077 sec)
# INFO:tensorflow:loss = 432.97278, step = 8700 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1190.21
# INFO:tensorflow:global_step/sec: 1190.21
# INFO:tensorflow:loss = 331.1199, step = 8800 (0.083 sec)
# INFO:tensorflow:loss = 331.1199, step = 8800 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1282.44
# INFO:tensorflow:global_step/sec: 1282.44
# INFO:tensorflow:loss = 293.02045, step = 8900 (0.079 sec)
# INFO:tensorflow:loss = 293.02045, step = 8900 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1249.64
# INFO:tensorflow:global_step/sec: 1249.64
# INFO:tensorflow:loss = 300.35397, step = 9000 (0.080 sec)
# INFO:tensorflow:loss = 300.35397, step = 9000 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1162.89
# INFO:tensorflow:global_step/sec: 1162.89
# INFO:tensorflow:loss = 183.75659, step = 9100 (0.087 sec)
# INFO:tensorflow:loss = 183.75659, step = 9100 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1075.43
# INFO:tensorflow:global_step/sec: 1075.43
# INFO:tensorflow:loss = 303.32706, step = 9200 (0.093 sec)
# INFO:tensorflow:loss = 303.32706, step = 9200 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:loss = 297.23914, step = 9300 (0.080 sec)
# INFO:tensorflow:loss = 297.23914, step = 9300 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1265.8
# INFO:tensorflow:global_step/sec: 1265.8
# INFO:tensorflow:loss = 297.0723, step = 9400 (0.078 sec)
# INFO:tensorflow:loss = 297.0723, step = 9400 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1351.38
# INFO:tensorflow:global_step/sec: 1351.38
# INFO:tensorflow:loss = 215.81964, step = 9500 (0.074 sec)
# INFO:tensorflow:loss = 215.81964, step = 9500 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1470.56
# INFO:tensorflow:global_step/sec: 1470.56
# INFO:tensorflow:loss = 144.50076, step = 9600 (0.069 sec)
# INFO:tensorflow:loss = 144.50076, step = 9600 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1369.89
# INFO:tensorflow:global_step/sec: 1369.89
# INFO:tensorflow:loss = 209.0603, step = 9700 (0.073 sec)
# INFO:tensorflow:loss = 209.0603, step = 9700 (0.073 sec)
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:loss = 215.85486, step = 9800 (0.072 sec)
# INFO:tensorflow:loss = 215.85486, step = 9800 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:loss = 186.03906, step = 9900 (0.082 sec)
# INFO:tensorflow:loss = 186.03906, step = 9900 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1219.49
# INFO:tensorflow:global_step/sec: 1219.49
# INFO:tensorflow:loss = 125.91775, step = 10000 (0.081 sec)
# INFO:tensorflow:loss = 125.91775, step = 10000 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:global_step/sec: 1234.58
# INFO:tensorflow:loss = 233.5191, step = 10100 (0.082 sec)
# INFO:tensorflow:loss = 233.5191, step = 10100 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1282.05
# INFO:tensorflow:global_step/sec: 1282.05
# INFO:tensorflow:loss = 154.26413, step = 10200 (0.078 sec)
# INFO:tensorflow:loss = 154.26413, step = 10200 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1333.32
# INFO:tensorflow:global_step/sec: 1333.32
# INFO:tensorflow:loss = 151.42157, step = 10300 (0.075 sec)
# INFO:tensorflow:loss = 151.42157, step = 10300 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1449.28
# INFO:tensorflow:global_step/sec: 1449.28
# INFO:tensorflow:loss = 208.44653, step = 10400 (0.069 sec)
# INFO:tensorflow:loss = 208.44653, step = 10400 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1448.87
# INFO:tensorflow:global_step/sec: 1448.87
# INFO:tensorflow:loss = 153.95758, step = 10500 (0.069 sec)
# INFO:tensorflow:loss = 153.95758, step = 10500 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1219.43
# INFO:tensorflow:global_step/sec: 1219.43
# INFO:tensorflow:loss = 186.46036, step = 10600 (0.083 sec)
# INFO:tensorflow:loss = 186.46036, step = 10600 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1316.19
# INFO:tensorflow:global_step/sec: 1316.19
# INFO:tensorflow:loss = 263.7981, step = 10700 (0.075 sec)
# INFO:tensorflow:loss = 263.7981, step = 10700 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1333.04
# INFO:tensorflow:global_step/sec: 1333.04
# INFO:tensorflow:loss = 140.97372, step = 10800 (0.075 sec)
# INFO:tensorflow:loss = 140.97372, step = 10800 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1333.6
# INFO:tensorflow:global_step/sec: 1333.6
# INFO:tensorflow:loss = 286.57214, step = 10900 (0.074 sec)
# INFO:tensorflow:loss = 286.57214, step = 10900 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1351.37
# INFO:tensorflow:global_step/sec: 1351.37
# INFO:tensorflow:loss = 228.90732, step = 11000 (0.074 sec)
# INFO:tensorflow:loss = 228.90732, step = 11000 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:loss = 214.52348, step = 11100 (0.074 sec)
# INFO:tensorflow:loss = 214.52348, step = 11100 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1282.07
# INFO:tensorflow:global_step/sec: 1282.07
# INFO:tensorflow:loss = 160.8442, step = 11200 (0.078 sec)
# INFO:tensorflow:loss = 160.8442, step = 11200 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1408.45
# INFO:tensorflow:global_step/sec: 1408.45
# INFO:tensorflow:loss = 224.89847, step = 11300 (0.071 sec)
# INFO:tensorflow:loss = 224.89847, step = 11300 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1315.81
# INFO:tensorflow:global_step/sec: 1315.81
# INFO:tensorflow:loss = 129.21297, step = 11400 (0.075 sec)
# INFO:tensorflow:loss = 129.21297, step = 11400 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1265.51
# INFO:tensorflow:global_step/sec: 1265.51
# INFO:tensorflow:loss = 171.14276, step = 11500 (0.080 sec)
# INFO:tensorflow:loss = 171.14276, step = 11500 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1219.78
# INFO:tensorflow:global_step/sec: 1219.78
# INFO:tensorflow:loss = 171.17075, step = 11600 (0.083 sec)
# INFO:tensorflow:loss = 171.17075, step = 11600 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1176.17
# INFO:tensorflow:global_step/sec: 1176.17
# INFO:tensorflow:loss = 121.45671, step = 11700 (0.083 sec)
# INFO:tensorflow:loss = 121.45671, step = 11700 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1316.13
# INFO:tensorflow:global_step/sec: 1316.13
# INFO:tensorflow:loss = 200.55087, step = 11800 (0.076 sec)
# INFO:tensorflow:loss = 200.55087, step = 11800 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1315.82
# INFO:tensorflow:global_step/sec: 1315.82
# INFO:tensorflow:loss = 192.76971, step = 11900 (0.076 sec)
# INFO:tensorflow:loss = 192.76971, step = 11900 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1030.91
# INFO:tensorflow:global_step/sec: 1030.91
# INFO:tensorflow:loss = 120.94733, step = 12000 (0.097 sec)
# INFO:tensorflow:loss = 120.94733, step = 12000 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1234.59
# INFO:tensorflow:global_step/sec: 1234.59
# INFO:tensorflow:loss = 113.384796, step = 12100 (0.082 sec)
# INFO:tensorflow:loss = 113.384796, step = 12100 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1333.02
# INFO:tensorflow:global_step/sec: 1333.02
# INFO:tensorflow:loss = 134.91232, step = 12200 (0.075 sec)
# INFO:tensorflow:loss = 134.91232, step = 12200 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1234.84
# INFO:tensorflow:global_step/sec: 1234.84
# INFO:tensorflow:loss = 166.56104, step = 12300 (0.081 sec)
# INFO:tensorflow:loss = 166.56104, step = 12300 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1351.03
# INFO:tensorflow:global_step/sec: 1351.03
# INFO:tensorflow:loss = 208.16171, step = 12400 (0.074 sec)
# INFO:tensorflow:loss = 208.16171, step = 12400 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1351.66
# INFO:tensorflow:global_step/sec: 1351.66
# INFO:tensorflow:loss = 137.02675, step = 12500 (0.074 sec)
# INFO:tensorflow:loss = 137.02675, step = 12500 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:loss = 176.66016, step = 12600 (0.076 sec)
# INFO:tensorflow:loss = 176.66016, step = 12600 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1219.54
# INFO:tensorflow:global_step/sec: 1219.54
# INFO:tensorflow:loss = 177.35146, step = 12700 (0.081 sec)
# INFO:tensorflow:loss = 177.35146, step = 12700 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1265.75
# INFO:tensorflow:global_step/sec: 1265.75
# INFO:tensorflow:loss = 129.30717, step = 12800 (0.080 sec)
# INFO:tensorflow:loss = 129.30717, step = 12800 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1234.62
# INFO:tensorflow:global_step/sec: 1234.62
# INFO:tensorflow:loss = 154.00394, step = 12900 (0.081 sec)
# INFO:tensorflow:loss = 154.00394, step = 12900 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1219.46
# INFO:tensorflow:global_step/sec: 1219.46
# INFO:tensorflow:loss = 155.01477, step = 13000 (0.082 sec)
# INFO:tensorflow:loss = 155.01477, step = 13000 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1149.43
# INFO:tensorflow:global_step/sec: 1149.43
# INFO:tensorflow:loss = 192.2425, step = 13100 (0.087 sec)
# INFO:tensorflow:loss = 192.2425, step = 13100 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1162.79
# INFO:tensorflow:global_step/sec: 1162.79
# INFO:tensorflow:loss = 155.892, step = 13200 (0.086 sec)
# INFO:tensorflow:loss = 155.892, step = 13200 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1250.03
# INFO:tensorflow:global_step/sec: 1250.03
# INFO:tensorflow:loss = 188.76337, step = 13300 (0.080 sec)
# INFO:tensorflow:loss = 188.76337, step = 13300 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1265.82
# INFO:tensorflow:global_step/sec: 1265.82
# INFO:tensorflow:loss = 94.21843, step = 13400 (0.079 sec)
# INFO:tensorflow:loss = 94.21843, step = 13400 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1369.94
# INFO:tensorflow:global_step/sec: 1369.94
# INFO:tensorflow:loss = 92.75194, step = 13500 (0.072 sec)
# INFO:tensorflow:loss = 92.75194, step = 13500 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1408.41
# INFO:tensorflow:global_step/sec: 1408.41
# INFO:tensorflow:loss = 124.747986, step = 13600 (0.072 sec)
# INFO:tensorflow:loss = 124.747986, step = 13600 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1282.06
# INFO:tensorflow:global_step/sec: 1282.06
# INFO:tensorflow:loss = 178.58765, step = 13700 (0.078 sec)
# INFO:tensorflow:loss = 178.58765, step = 13700 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1249.98
# INFO:tensorflow:global_step/sec: 1249.98
# INFO:tensorflow:loss = 106.93126, step = 13800 (0.080 sec)
# INFO:tensorflow:loss = 106.93126, step = 13800 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1265.85
# INFO:tensorflow:global_step/sec: 1265.85
# INFO:tensorflow:loss = 98.56778, step = 13900 (0.078 sec)
# INFO:tensorflow:loss = 98.56778, step = 13900 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:loss = 106.624466, step = 14000 (0.083 sec)
# INFO:tensorflow:loss = 106.624466, step = 14000 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1162.78
# INFO:tensorflow:global_step/sec: 1162.78
# INFO:tensorflow:loss = 81.41225, step = 14100 (0.087 sec)
# INFO:tensorflow:loss = 81.41225, step = 14100 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1136.3
# INFO:tensorflow:global_step/sec: 1136.3
# INFO:tensorflow:loss = 103.80122, step = 14200 (0.088 sec)
# INFO:tensorflow:loss = 103.80122, step = 14200 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1198.96
# INFO:tensorflow:global_step/sec: 1198.96
# INFO:tensorflow:loss = 120.05483, step = 14300 (0.083 sec)
# INFO:tensorflow:loss = 120.05483, step = 14300 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1305.62
# INFO:tensorflow:global_step/sec: 1305.62
# INFO:tensorflow:loss = 174.88385, step = 14400 (0.077 sec)
# INFO:tensorflow:loss = 174.88385, step = 14400 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1265.57
# INFO:tensorflow:global_step/sec: 1265.57
# INFO:tensorflow:loss = 125.604225, step = 14500 (0.078 sec)
# INFO:tensorflow:loss = 125.604225, step = 14500 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1204.92
# INFO:tensorflow:global_step/sec: 1204.92
# INFO:tensorflow:loss = 119.7746, step = 14600 (0.085 sec)
# INFO:tensorflow:loss = 119.7746, step = 14600 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1041.76
# INFO:tensorflow:global_step/sec: 1041.76
# INFO:tensorflow:loss = 111.987625, step = 14700 (0.094 sec)
# INFO:tensorflow:loss = 111.987625, step = 14700 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1123.6
# INFO:tensorflow:global_step/sec: 1123.6
# INFO:tensorflow:loss = 173.0412, step = 14800 (0.089 sec)
# INFO:tensorflow:loss = 173.0412, step = 14800 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1298.74
# INFO:tensorflow:global_step/sec: 1298.74
# INFO:tensorflow:loss = 107.95234, step = 14900 (0.078 sec)
# INFO:tensorflow:loss = 107.95234, step = 14900 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1515.15
# INFO:tensorflow:global_step/sec: 1515.15
# INFO:tensorflow:loss = 151.22849, step = 15000 (0.065 sec)
# INFO:tensorflow:loss = 151.22849, step = 15000 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1538.48
# INFO:tensorflow:global_step/sec: 1538.48
# INFO:tensorflow:loss = 85.66447, step = 15100 (0.066 sec)
# INFO:tensorflow:loss = 85.66447, step = 15100 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:loss = 48.69146, step = 15200 (0.076 sec)
# INFO:tensorflow:loss = 48.69146, step = 15200 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:loss = 49.624, step = 15300 (0.084 sec)
# INFO:tensorflow:loss = 49.624, step = 15300 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1282.01
# INFO:tensorflow:global_step/sec: 1282.01
# INFO:tensorflow:loss = 99.98839, step = 15400 (0.077 sec)
# INFO:tensorflow:loss = 99.98839, step = 15400 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1234.57
# INFO:tensorflow:global_step/sec: 1234.57
# INFO:tensorflow:loss = 69.91867, step = 15500 (0.081 sec)
# INFO:tensorflow:loss = 69.91867, step = 15500 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1298.76
# INFO:tensorflow:global_step/sec: 1298.76
# INFO:tensorflow:loss = 126.68538, step = 15600 (0.076 sec)
# INFO:tensorflow:loss = 126.68538, step = 15600 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1470.52
# INFO:tensorflow:global_step/sec: 1470.52
# INFO:tensorflow:loss = 52.40471, step = 15700 (0.069 sec)
# INFO:tensorflow:loss = 52.40471, step = 15700 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1333.39
# INFO:tensorflow:global_step/sec: 1333.39
# INFO:tensorflow:loss = 84.45633, step = 15800 (0.074 sec)
# INFO:tensorflow:loss = 84.45633, step = 15800 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1369.85
# INFO:tensorflow:global_step/sec: 1369.85
# INFO:tensorflow:loss = 66.91962, step = 15900 (0.073 sec)
# INFO:tensorflow:loss = 66.91962, step = 15900 (0.073 sec)
# INFO:tensorflow:global_step/sec: 1265.8
# INFO:tensorflow:global_step/sec: 1265.8
# INFO:tensorflow:loss = 100.859566, step = 16000 (0.080 sec)
# INFO:tensorflow:loss = 100.859566, step = 16000 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1265.84
# INFO:tensorflow:global_step/sec: 1265.84
# INFO:tensorflow:loss = 72.01724, step = 16100 (0.078 sec)
# INFO:tensorflow:loss = 72.01724, step = 16100 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1351.35
# INFO:tensorflow:global_step/sec: 1351.35
# INFO:tensorflow:loss = 42.644344, step = 16200 (0.074 sec)
# INFO:tensorflow:loss = 42.644344, step = 16200 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1298.7
# INFO:tensorflow:global_step/sec: 1298.7
# INFO:tensorflow:loss = 54.224487, step = 16300 (0.078 sec)
# INFO:tensorflow:loss = 54.224487, step = 16300 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1315.82
# INFO:tensorflow:global_step/sec: 1315.82
# INFO:tensorflow:loss = 70.34865, step = 16400 (0.075 sec)
# INFO:tensorflow:loss = 70.34865, step = 16400 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1204.74
# INFO:tensorflow:global_step/sec: 1204.74
# INFO:tensorflow:loss = 58.25044, step = 16500 (0.084 sec)
# INFO:tensorflow:loss = 58.25044, step = 16500 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1219.57
# INFO:tensorflow:global_step/sec: 1219.57
# INFO:tensorflow:loss = 73.38573, step = 16600 (0.082 sec)
# INFO:tensorflow:loss = 73.38573, step = 16600 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1249.98
# INFO:tensorflow:global_step/sec: 1249.98
# INFO:tensorflow:loss = 57.117622, step = 16700 (0.080 sec)
# INFO:tensorflow:loss = 57.117622, step = 16700 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1388.9
# INFO:tensorflow:global_step/sec: 1388.9
# INFO:tensorflow:loss = 57.627995, step = 16800 (0.072 sec)
# INFO:tensorflow:loss = 57.627995, step = 16800 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1162.55
# INFO:tensorflow:global_step/sec: 1162.55
# INFO:tensorflow:loss = 124.81293, step = 16900 (0.086 sec)
# INFO:tensorflow:loss = 124.81293, step = 16900 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1408.77
# INFO:tensorflow:global_step/sec: 1408.77
# INFO:tensorflow:loss = 76.83917, step = 17000 (0.071 sec)
# INFO:tensorflow:loss = 76.83917, step = 17000 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1282.1
# INFO:tensorflow:global_step/sec: 1282.1
# INFO:tensorflow:loss = 84.690254, step = 17100 (0.078 sec)
# INFO:tensorflow:loss = 84.690254, step = 17100 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1190.42
# INFO:tensorflow:global_step/sec: 1190.42
# INFO:tensorflow:loss = 79.675446, step = 17200 (0.085 sec)
# INFO:tensorflow:loss = 79.675446, step = 17200 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1123.63
# INFO:tensorflow:global_step/sec: 1123.63
# INFO:tensorflow:loss = 40.43152, step = 17300 (0.088 sec)
# INFO:tensorflow:loss = 40.43152, step = 17300 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1282.07
# INFO:tensorflow:global_step/sec: 1282.07
# INFO:tensorflow:loss = 52.34387, step = 17400 (0.077 sec)
# INFO:tensorflow:loss = 52.34387, step = 17400 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1351.35
# INFO:tensorflow:global_step/sec: 1351.35
# INFO:tensorflow:loss = 52.08619, step = 17500 (0.074 sec)
# INFO:tensorflow:loss = 52.08619, step = 17500 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1265.84
# INFO:tensorflow:global_step/sec: 1265.84
# INFO:tensorflow:loss = 63.537834, step = 17600 (0.079 sec)
# INFO:tensorflow:loss = 63.537834, step = 17600 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:loss = 41.326736, step = 17700 (0.071 sec)
# INFO:tensorflow:loss = 41.326736, step = 17700 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1333.33
# INFO:tensorflow:global_step/sec: 1333.33
# INFO:tensorflow:loss = 86.693886, step = 17800 (0.074 sec)
# INFO:tensorflow:loss = 86.693886, step = 17800 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1282.01
# INFO:tensorflow:global_step/sec: 1282.01
# INFO:tensorflow:loss = 33.883083, step = 17900 (0.078 sec)
# INFO:tensorflow:loss = 33.883083, step = 17900 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1219.33
# INFO:tensorflow:global_step/sec: 1219.33
# INFO:tensorflow:loss = 49.041332, step = 18000 (0.083 sec)
# INFO:tensorflow:loss = 49.041332, step = 18000 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1234.81
# INFO:tensorflow:global_step/sec: 1234.81
# INFO:tensorflow:loss = 100.86577, step = 18100 (0.081 sec)
# INFO:tensorflow:loss = 100.86577, step = 18100 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1282.03
# INFO:tensorflow:global_step/sec: 1282.03
# INFO:tensorflow:loss = 40.544632, step = 18200 (0.078 sec)
# INFO:tensorflow:loss = 40.544632, step = 18200 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:loss = 69.39764, step = 18300 (0.075 sec)
# INFO:tensorflow:loss = 69.39764, step = 18300 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1265.83
# INFO:tensorflow:global_step/sec: 1265.83
# INFO:tensorflow:loss = 27.388027, step = 18400 (0.078 sec)
# INFO:tensorflow:loss = 27.388027, step = 18400 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1176.45
# INFO:tensorflow:global_step/sec: 1176.45
# INFO:tensorflow:loss = 18.448088, step = 18500 (0.086 sec)
# INFO:tensorflow:loss = 18.448088, step = 18500 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1123.57
# INFO:tensorflow:global_step/sec: 1123.57
# INFO:tensorflow:loss = 26.331682, step = 18600 (0.089 sec)
# INFO:tensorflow:loss = 26.331682, step = 18600 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1162.81
# INFO:tensorflow:global_step/sec: 1162.81
# INFO:tensorflow:loss = 56.335613, step = 18700 (0.086 sec)
# INFO:tensorflow:loss = 56.335613, step = 18700 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:global_step/sec: 1333.35
# INFO:tensorflow:loss = 48.368614, step = 18800 (0.074 sec)
# INFO:tensorflow:loss = 48.368614, step = 18800 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1515.12
# INFO:tensorflow:global_step/sec: 1515.12
# INFO:tensorflow:loss = 86.008255, step = 18900 (0.067 sec)
# INFO:tensorflow:loss = 86.008255, step = 18900 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1388.56
# INFO:tensorflow:global_step/sec: 1388.56
# INFO:tensorflow:loss = 23.266537, step = 19000 (0.072 sec)
# INFO:tensorflow:loss = 23.266537, step = 19000 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1234.81
# INFO:tensorflow:global_step/sec: 1234.81
# INFO:tensorflow:loss = 8.571866, step = 19100 (0.081 sec)
# INFO:tensorflow:loss = 8.571866, step = 19100 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1351.42
# INFO:tensorflow:global_step/sec: 1351.42
# INFO:tensorflow:loss = 14.555707, step = 19200 (0.073 sec)
# INFO:tensorflow:loss = 14.555707, step = 19200 (0.073 sec)
# INFO:tensorflow:global_step/sec: 1136.34
# INFO:tensorflow:global_step/sec: 1136.34
# INFO:tensorflow:loss = 9.641828, step = 19300 (0.089 sec)
# INFO:tensorflow:loss = 9.641828, step = 19300 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1204.83
# INFO:tensorflow:global_step/sec: 1204.83
# INFO:tensorflow:loss = 35.170273, step = 19400 (0.082 sec)
# INFO:tensorflow:loss = 35.170273, step = 19400 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1265.53
# INFO:tensorflow:global_step/sec: 1265.53
# INFO:tensorflow:loss = 35.453323, step = 19500 (0.079 sec)
# INFO:tensorflow:loss = 35.453323, step = 19500 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1428.92
# INFO:tensorflow:global_step/sec: 1428.92
# INFO:tensorflow:loss = 81.302216, step = 19600 (0.071 sec)
# INFO:tensorflow:loss = 81.302216, step = 19600 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1492.58
# INFO:tensorflow:global_step/sec: 1492.58
# INFO:tensorflow:loss = 31.687397, step = 19700 (0.066 sec)
# INFO:tensorflow:loss = 31.687397, step = 19700 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1428.53
# INFO:tensorflow:global_step/sec: 1428.53
# INFO:tensorflow:loss = 31.728365, step = 19800 (0.071 sec)
# INFO:tensorflow:loss = 31.728365, step = 19800 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1298.67
# INFO:tensorflow:global_step/sec: 1298.67
# INFO:tensorflow:loss = 55.82441, step = 19900 (0.078 sec)
# INFO:tensorflow:loss = 55.82441, step = 19900 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1176.5
# INFO:tensorflow:global_step/sec: 1176.5
# INFO:tensorflow:loss = 22.891182, step = 20000 (0.083 sec)
# INFO:tensorflow:loss = 22.891182, step = 20000 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1149.42
# INFO:tensorflow:global_step/sec: 1149.42
# INFO:tensorflow:loss = 18.47153, step = 20100 (0.087 sec)
# INFO:tensorflow:loss = 18.47153, step = 20100 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:global_step/sec: 1369.88
# INFO:tensorflow:loss = 19.407013, step = 20200 (0.073 sec)
# INFO:tensorflow:loss = 19.407013, step = 20200 (0.073 sec)
# INFO:tensorflow:global_step/sec: 1298.72
# INFO:tensorflow:global_step/sec: 1298.72
# INFO:tensorflow:loss = 39.98284, step = 20300 (0.077 sec)
# INFO:tensorflow:loss = 39.98284, step = 20300 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1315.36
# INFO:tensorflow:global_step/sec: 1315.36
# INFO:tensorflow:loss = 33.082436, step = 20400 (0.077 sec)
# INFO:tensorflow:loss = 33.082436, step = 20400 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1333.34
# INFO:tensorflow:global_step/sec: 1333.34
# INFO:tensorflow:loss = 36.617058, step = 20500 (0.075 sec)
# INFO:tensorflow:loss = 36.617058, step = 20500 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1190.48
# INFO:tensorflow:global_step/sec: 1190.48
# INFO:tensorflow:loss = 34.331543, step = 20600 (0.084 sec)
# INFO:tensorflow:loss = 34.331543, step = 20600 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1136.66
# INFO:tensorflow:global_step/sec: 1136.66
# INFO:tensorflow:loss = 35.452614, step = 20700 (0.088 sec)
# INFO:tensorflow:loss = 35.452614, step = 20700 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1190.45
# INFO:tensorflow:global_step/sec: 1190.45
# INFO:tensorflow:loss = 19.814178, step = 20800 (0.085 sec)
# INFO:tensorflow:loss = 19.814178, step = 20800 (0.085 sec)
# INFO:tensorflow:global_step/sec: 1176.47
# INFO:tensorflow:global_step/sec: 1176.47
# INFO:tensorflow:loss = 26.180908, step = 20900 (0.084 sec)
# INFO:tensorflow:loss = 26.180908, step = 20900 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1234.64
# INFO:tensorflow:global_step/sec: 1234.64
# INFO:tensorflow:loss = 29.542227, step = 21000 (0.081 sec)
# INFO:tensorflow:loss = 29.542227, step = 21000 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1218.98
# INFO:tensorflow:global_step/sec: 1218.98
# INFO:tensorflow:loss = 30.062712, step = 21100 (0.083 sec)
# INFO:tensorflow:loss = 30.062712, step = 21100 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1136.78
# INFO:tensorflow:global_step/sec: 1136.78
# INFO:tensorflow:loss = 26.760963, step = 21200 (0.088 sec)
# INFO:tensorflow:loss = 26.760963, step = 21200 (0.088 sec)
# INFO:tensorflow:global_step/sec: 980.381
# INFO:tensorflow:global_step/sec: 980.381
# INFO:tensorflow:loss = 29.710266, step = 21300 (0.102 sec)
# INFO:tensorflow:loss = 29.710266, step = 21300 (0.102 sec)
# INFO:tensorflow:global_step/sec: 952.415
# INFO:tensorflow:global_step/sec: 952.415
# INFO:tensorflow:loss = 27.7776, step = 21400 (0.104 sec)
# INFO:tensorflow:loss = 27.7776, step = 21400 (0.104 sec)
# INFO:tensorflow:global_step/sec: 1136.33
# INFO:tensorflow:global_step/sec: 1136.33
# INFO:tensorflow:loss = 57.402916, step = 21500 (0.088 sec)
# INFO:tensorflow:loss = 57.402916, step = 21500 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1249.74
# INFO:tensorflow:global_step/sec: 1249.74
# INFO:tensorflow:loss = 15.058262, step = 21600 (0.081 sec)
# INFO:tensorflow:loss = 15.058262, step = 21600 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1408.82
# INFO:tensorflow:global_step/sec: 1408.82
# INFO:tensorflow:loss = 13.905505, step = 21700 (0.070 sec)
# INFO:tensorflow:loss = 13.905505, step = 21700 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1298.7
# INFO:tensorflow:global_step/sec: 1298.7
# INFO:tensorflow:loss = 8.256999, step = 21800 (0.077 sec)
# INFO:tensorflow:loss = 8.256999, step = 21800 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:global_step/sec: 1204.82
# INFO:tensorflow:loss = 36.165, step = 21900 (0.083 sec)
# INFO:tensorflow:loss = 36.165, step = 21900 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1234.57
# INFO:tensorflow:global_step/sec: 1234.57
# INFO:tensorflow:loss = 26.826769, step = 22000 (0.080 sec)
# INFO:tensorflow:loss = 26.826769, step = 22000 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1408.47
# INFO:tensorflow:global_step/sec: 1408.47
# INFO:tensorflow:loss = 33.066135, step = 22100 (0.072 sec)
# INFO:tensorflow:loss = 33.066135, step = 22100 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1369.86
# INFO:tensorflow:global_step/sec: 1369.86
# ...
# INFO:tensorflow:loss = 17.434685, step = 32200 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1449.24
# INFO:tensorflow:global_step/sec: 1449.24
# INFO:tensorflow:loss = 32.33131, step = 32300 (0.070 sec)
# INFO:tensorflow:loss = 32.33131, step = 32300 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1492.58
# INFO:tensorflow:global_step/sec: 1492.58
# INFO:tensorflow:loss = 20.21226, step = 32400 (0.066 sec)
# INFO:tensorflow:loss = 20.21226, step = 32400 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1236.69
# INFO:tensorflow:global_step/sec: 1236.69
# INFO:tensorflow:loss = 4.831376, step = 32500 (0.081 sec)
# INFO:tensorflow:loss = 4.831376, step = 32500 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1467.98
# INFO:tensorflow:global_step/sec: 1467.98
# INFO:tensorflow:loss = 26.99275, step = 32600 (0.069 sec)
# INFO:tensorflow:loss = 26.99275, step = 32600 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1240.43
# INFO:tensorflow:global_step/sec: 1240.43
# INFO:tensorflow:loss = 46.239136, step = 32700 (0.081 sec)
# INFO:tensorflow:loss = 46.239136, step = 32700 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1234.74
# INFO:tensorflow:global_step/sec: 1234.74
# INFO:tensorflow:loss = 5.575431, step = 32800 (0.081 sec)
# INFO:tensorflow:loss = 5.575431, step = 32800 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1310.97
# INFO:tensorflow:global_step/sec: 1310.97
# INFO:tensorflow:loss = 17.32807, step = 32900 (0.075 sec)
# INFO:tensorflow:loss = 17.32807, step = 32900 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1339.54
# INFO:tensorflow:global_step/sec: 1339.54
# INFO:tensorflow:loss = 18.166819, step = 33000 (0.075 sec)
# INFO:tensorflow:loss = 18.166819, step = 33000 (0.075 sec)
# INFO:tensorflow:global_step/sec: 1538.47
# INFO:tensorflow:global_step/sec: 1538.47
# INFO:tensorflow:loss = 9.378091, step = 33100 (0.065 sec)
# INFO:tensorflow:loss = 9.378091, step = 33100 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1230.82
# INFO:tensorflow:global_step/sec: 1230.82
# INFO:tensorflow:loss = 10.135737, step = 33200 (0.082 sec)
# INFO:tensorflow:loss = 10.135737, step = 33200 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1267.42
# INFO:tensorflow:global_step/sec: 1267.42
# INFO:tensorflow:loss = 5.3510256, step = 33300 (0.079 sec)
# INFO:tensorflow:loss = 5.3510256, step = 33300 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1302.86
# INFO:tensorflow:global_step/sec: 1302.86
# INFO:tensorflow:loss = 8.583977, step = 33400 (0.076 sec)
# INFO:tensorflow:loss = 8.583977, step = 33400 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1252.4
# INFO:tensorflow:global_step/sec: 1252.4
# INFO:tensorflow:loss = 7.3560157, step = 33500 (0.082 sec)
# INFO:tensorflow:loss = 7.3560157, step = 33500 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:loss = 19.445831, step = 33600 (0.069 sec)
# INFO:tensorflow:loss = 19.445831, step = 33600 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1492.54
# INFO:tensorflow:global_step/sec: 1492.54
# INFO:tensorflow:loss = 6.874283, step = 33700 (0.066 sec)
# INFO:tensorflow:loss = 6.874283, step = 33700 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1562.51
# INFO:tensorflow:global_step/sec: 1562.51
# INFO:tensorflow:loss = 21.128807, step = 33800 (0.065 sec)
# INFO:tensorflow:loss = 21.128807, step = 33800 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1612.9
# INFO:tensorflow:global_step/sec: 1612.9
# INFO:tensorflow:loss = 13.58991, step = 33900 (0.062 sec)
# INFO:tensorflow:loss = 13.58991, step = 33900 (0.062 sec)
# INFO:tensorflow:global_step/sec: 1562.55
# INFO:tensorflow:global_step/sec: 1562.55
# INFO:tensorflow:loss = 37.63649, step = 34000 (0.063 sec)
# INFO:tensorflow:loss = 37.63649, step = 34000 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1041.66
# INFO:tensorflow:global_step/sec: 1041.66
# INFO:tensorflow:loss = 14.218285, step = 34100 (0.097 sec)
# INFO:tensorflow:loss = 14.218285, step = 34100 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:global_step/sec: 1428.54
# INFO:tensorflow:loss = 31.23935, step = 34200 (0.069 sec)
# INFO:tensorflow:loss = 31.23935, step = 34200 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1449.2
# INFO:tensorflow:global_step/sec: 1449.2
# INFO:tensorflow:loss = 9.858131, step = 34300 (0.070 sec)
# INFO:tensorflow:loss = 9.858131, step = 34300 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1470.63
# INFO:tensorflow:global_step/sec: 1470.63
# INFO:tensorflow:loss = 25.843348, step = 34400 (0.067 sec)
# INFO:tensorflow:loss = 25.843348, step = 34400 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1538.55
# INFO:tensorflow:global_step/sec: 1538.55
# INFO:tensorflow:loss = 20.882954, step = 34500 (0.066 sec)
# INFO:tensorflow:loss = 20.882954, step = 34500 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1098.87
# INFO:tensorflow:global_step/sec: 1098.87
# INFO:tensorflow:loss = 32.402805, step = 34600 (0.092 sec)
# INFO:tensorflow:loss = 32.402805, step = 34600 (0.092 sec)
# INFO:tensorflow:global_step/sec: 1075.27
# INFO:tensorflow:global_step/sec: 1075.27
# INFO:tensorflow:loss = 2.8729656, step = 34700 (0.093 sec)
# INFO:tensorflow:loss = 2.8729656, step = 34700 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1265.83
# INFO:tensorflow:global_step/sec: 1265.83
# INFO:tensorflow:loss = 17.137299, step = 34800 (0.078 sec)
# INFO:tensorflow:loss = 17.137299, step = 34800 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1234.55
# INFO:tensorflow:global_step/sec: 1234.55
# INFO:tensorflow:loss = 12.58621, step = 34900 (0.081 sec)
# INFO:tensorflow:loss = 12.58621, step = 34900 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1408.48
# INFO:tensorflow:global_step/sec: 1408.48
# INFO:tensorflow:loss = 18.389618, step = 35000 (0.071 sec)
# INFO:tensorflow:loss = 18.389618, step = 35000 (0.071 sec)
# INFO:tensorflow:global_step/sec: 1562.46
# INFO:tensorflow:global_step/sec: 1562.46
# INFO:tensorflow:loss = 55.715557, step = 35100 (0.063 sec)
# INFO:tensorflow:loss = 55.715557, step = 35100 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1562.57
# INFO:tensorflow:global_step/sec: 1562.57
# INFO:tensorflow:loss = 40.44688, step = 35200 (0.064 sec)
# INFO:tensorflow:loss = 40.44688, step = 35200 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1449.25
# INFO:tensorflow:global_step/sec: 1449.25
# INFO:tensorflow:loss = 32.236393, step = 35300 (0.069 sec)
# INFO:tensorflow:loss = 32.236393, step = 35300 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1276.03
# INFO:tensorflow:global_step/sec: 1276.03
# INFO:tensorflow:loss = 8.973522, step = 35400 (0.079 sec)
# INFO:tensorflow:loss = 8.973522, step = 35400 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:global_step/sec: 1315.78
# INFO:tensorflow:loss = 27.097374, step = 35500 (0.076 sec)
# INFO:tensorflow:loss = 27.097374, step = 35500 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1191.26
# INFO:tensorflow:global_step/sec: 1191.26
# INFO:tensorflow:loss = 14.59037, step = 35600 (0.084 sec)
# INFO:tensorflow:loss = 14.59037, step = 35600 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1208.2
# INFO:tensorflow:global_step/sec: 1208.2
# INFO:tensorflow:loss = 16.099852, step = 35700 (0.083 sec)
# INFO:tensorflow:loss = 16.099852, step = 35700 (0.083 sec)
# INFO:tensorflow:global_step/sec: 1428.59
# INFO:tensorflow:global_step/sec: 1428.59
# INFO:tensorflow:loss = 16.072323, step = 35800 (0.070 sec)
# INFO:tensorflow:loss = 16.072323, step = 35800 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1515.09
# INFO:tensorflow:global_step/sec: 1515.09
# INFO:tensorflow:loss = 17.406574, step = 35900 (0.067 sec)
# INFO:tensorflow:loss = 17.406574, step = 35900 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1268.76
# INFO:tensorflow:global_step/sec: 1268.76
# INFO:tensorflow:loss = 10.756416, step = 36000 (0.078 sec)
# INFO:tensorflow:loss = 10.756416, step = 36000 (0.078 sec)
# INFO:tensorflow:global_step/sec: 1470.65
# INFO:tensorflow:global_step/sec: 1470.65
# INFO:tensorflow:loss = 21.105045, step = 36100 (0.068 sec)
# INFO:tensorflow:loss = 21.105045, step = 36100 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1369.84
# INFO:tensorflow:global_step/sec: 1369.84
# INFO:tensorflow:loss = 9.566753, step = 36200 (0.072 sec)
# INFO:tensorflow:loss = 9.566753, step = 36200 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1150.01
# INFO:tensorflow:global_step/sec: 1150.01
# INFO:tensorflow:loss = 25.40016, step = 36300 (0.088 sec)
# INFO:tensorflow:loss = 25.40016, step = 36300 (0.088 sec)
# INFO:tensorflow:global_step/sec: 1123.49
# INFO:tensorflow:global_step/sec: 1123.49
# INFO:tensorflow:loss = 41.804443, step = 36400 (0.089 sec)
# INFO:tensorflow:loss = 41.804443, step = 36400 (0.089 sec)
# INFO:tensorflow:global_step/sec: 1389.06
# INFO:tensorflow:global_step/sec: 1389.06
# INFO:tensorflow:loss = 22.588451, step = 36500 (0.072 sec)
# INFO:tensorflow:loss = 22.588451, step = 36500 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1612.94
# INFO:tensorflow:global_step/sec: 1612.94
# INFO:tensorflow:loss = 6.9739866, step = 36600 (0.062 sec)
# INFO:tensorflow:loss = 6.9739866, step = 36600 (0.062 sec)
# INFO:tensorflow:global_step/sec: 1562.5
# INFO:tensorflow:global_step/sec: 1562.5
# INFO:tensorflow:loss = 9.982758, step = 36700 (0.063 sec)
# INFO:tensorflow:loss = 9.982758, step = 36700 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1538.39
# INFO:tensorflow:global_step/sec: 1538.39
# INFO:tensorflow:loss = 38.69232, step = 36800 (0.065 sec)
# INFO:tensorflow:loss = 38.69232, step = 36800 (0.065 sec)
# INFO:tensorflow:global_step/sec: 1492.59
# INFO:tensorflow:global_step/sec: 1492.59
# INFO:tensorflow:loss = 21.018608, step = 36900 (0.067 sec)
# INFO:tensorflow:loss = 21.018608, step = 36900 (0.067 sec)
# INFO:tensorflow:global_step/sec: 1538.18
# INFO:tensorflow:global_step/sec: 1538.18
# INFO:tensorflow:loss = 14.462776, step = 37000 (0.066 sec)
# INFO:tensorflow:loss = 14.462776, step = 37000 (0.066 sec)
# INFO:tensorflow:global_step/sec: 1384.04
# INFO:tensorflow:global_step/sec: 1384.04
# INFO:tensorflow:loss = 10.6477375, step = 37100 (0.072 sec)
# INFO:tensorflow:loss = 10.6477375, step = 37100 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1612.86
# INFO:tensorflow:global_step/sec: 1612.86
# INFO:tensorflow:loss = 7.755634, step = 37200 (0.062 sec)
# INFO:tensorflow:loss = 7.755634, step = 37200 (0.062 sec)
# INFO:tensorflow:global_step/sec: 1612.95
# INFO:tensorflow:global_step/sec: 1612.95
# INFO:tensorflow:loss = 25.561268, step = 37300 (0.061 sec)
# INFO:tensorflow:loss = 25.561268, step = 37300 (0.061 sec)
# INFO:tensorflow:global_step/sec: 1388.63
# INFO:tensorflow:global_step/sec: 1388.63
# INFO:tensorflow:loss = 4.902714, step = 37400 (0.072 sec)
# INFO:tensorflow:loss = 4.902714, step = 37400 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1197.66
# INFO:tensorflow:global_step/sec: 1197.66
# INFO:tensorflow:loss = 9.540848, step = 37500 (0.084 sec)
# INFO:tensorflow:loss = 9.540848, step = 37500 (0.084 sec)
# INFO:tensorflow:global_step/sec: 1270.13
# INFO:tensorflow:global_step/sec: 1270.13
# INFO:tensorflow:loss = 8.386961, step = 37600 (0.079 sec)
# INFO:tensorflow:loss = 8.386961, step = 37600 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1408.77
# INFO:tensorflow:global_step/sec: 1408.77
# INFO:tensorflow:loss = 39.268898, step = 37700 (0.070 sec)
# INFO:tensorflow:loss = 39.268898, step = 37700 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1269.77
# INFO:tensorflow:global_step/sec: 1269.77
# INFO:tensorflow:loss = 7.8670106, step = 37800 (0.080 sec)
# INFO:tensorflow:loss = 7.8670106, step = 37800 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1162.8
# INFO:tensorflow:global_step/sec: 1162.8
# INFO:tensorflow:loss = 8.398976, step = 37900 (0.086 sec)
# INFO:tensorflow:loss = 8.398976, step = 37900 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1562.46
# INFO:tensorflow:global_step/sec: 1562.46
# INFO:tensorflow:loss = 33.07859, step = 38000 (0.063 sec)
# INFO:tensorflow:loss = 33.07859, step = 38000 (0.063 sec)
# INFO:tensorflow:global_step/sec: 1562.53
# INFO:tensorflow:global_step/sec: 1562.53
# INFO:tensorflow:loss = 13.066101, step = 38100 (0.064 sec)
# INFO:tensorflow:loss = 13.066101, step = 38100 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1576.14
# INFO:tensorflow:global_step/sec: 1576.14
# INFO:tensorflow:loss = 25.860538, step = 38200 (0.064 sec)
# INFO:tensorflow:loss = 25.860538, step = 38200 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1359.88
# INFO:tensorflow:global_step/sec: 1359.88
# INFO:tensorflow:loss = 9.847418, step = 38300 (0.074 sec)
# INFO:tensorflow:loss = 9.847418, step = 38300 (0.074 sec)
# INFO:tensorflow:global_step/sec: 1449.27
# INFO:tensorflow:global_step/sec: 1449.27
# INFO:tensorflow:loss = 15.74282, step = 38400 (0.070 sec)
# INFO:tensorflow:loss = 15.74282, step = 38400 (0.070 sec)
# INFO:tensorflow:global_step/sec: 1046.82
# INFO:tensorflow:global_step/sec: 1046.82
# INFO:tensorflow:loss = 6.9150643, step = 38500 (0.094 sec)
# INFO:tensorflow:loss = 6.9150643, step = 38500 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1410.92
# INFO:tensorflow:global_step/sec: 1410.92
# INFO:tensorflow:loss = 9.7938595, step = 38600 (0.072 sec)
# INFO:tensorflow:loss = 9.7938595, step = 38600 (0.072 sec)
# INFO:tensorflow:global_step/sec: 1587.31
# INFO:tensorflow:global_step/sec: 1587.31
# INFO:tensorflow:loss = 18.430243, step = 38700 (0.062 sec)
# INFO:tensorflow:loss = 18.430243, step = 38700 (0.062 sec)
# INFO:tensorflow:global_step/sec: 1249.48
# INFO:tensorflow:global_step/sec: 1249.48
# INFO:tensorflow:loss = 20.07226, step = 38800 (0.081 sec)
# INFO:tensorflow:loss = 20.07226, step = 38800 (0.081 sec)
# INFO:tensorflow:global_step/sec: 1295.21
# INFO:tensorflow:global_step/sec: 1295.21
# INFO:tensorflow:loss = 29.202911, step = 38900 (0.076 sec)
# INFO:tensorflow:loss = 29.202911, step = 38900 (0.076 sec)
# INFO:tensorflow:global_step/sec: 1287.75
# INFO:tensorflow:global_step/sec: 1287.75
# INFO:tensorflow:loss = 17.209667, step = 39000 (0.079 sec)
# INFO:tensorflow:loss = 17.209667, step = 39000 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1291.59
# INFO:tensorflow:global_step/sec: 1291.59
# INFO:tensorflow:loss = 10.756783, step = 39100 (0.077 sec)
# INFO:tensorflow:loss = 10.756783, step = 39100 (0.077 sec)
# INFO:tensorflow:global_step/sec: 1422.75
# INFO:tensorflow:global_step/sec: 1422.75
# INFO:tensorflow:loss = 15.737976, step = 39200 (0.069 sec)
# INFO:tensorflow:loss = 15.737976, step = 39200 (0.069 sec)
# INFO:tensorflow:global_step/sec: 1195.17
# INFO:tensorflow:global_step/sec: 1195.17
# INFO:tensorflow:loss = 10.813322, step = 39300 (0.086 sec)
# INFO:tensorflow:loss = 10.813322, step = 39300 (0.086 sec)
# INFO:tensorflow:global_step/sec: 1213.29
# INFO:tensorflow:global_step/sec: 1213.29
# INFO:tensorflow:loss = 15.986452, step = 39400 (0.080 sec)
# INFO:tensorflow:loss = 15.986452, step = 39400 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1481.87
# INFO:tensorflow:global_step/sec: 1481.87
# INFO:tensorflow:loss = 5.903581, step = 39500 (0.068 sec)
# INFO:tensorflow:loss = 5.903581, step = 39500 (0.068 sec)
# INFO:tensorflow:global_step/sec: 1244.33
# INFO:tensorflow:global_step/sec: 1244.33
# INFO:tensorflow:loss = 21.223804, step = 39600 (0.080 sec)
# INFO:tensorflow:loss = 21.223804, step = 39600 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1136.66
# INFO:tensorflow:global_step/sec: 1136.66
# INFO:tensorflow:loss = 25.434313, step = 39700 (0.087 sec)
# INFO:tensorflow:loss = 25.434313, step = 39700 (0.087 sec)
# INFO:tensorflow:global_step/sec: 1238.06
# INFO:tensorflow:global_step/sec: 1238.06
# INFO:tensorflow:loss = 19.826162, step = 39800 (0.082 sec)
# INFO:tensorflow:loss = 19.826162, step = 39800 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1538.79
# INFO:tensorflow:global_step/sec: 1538.79
# INFO:tensorflow:loss = 18.872822, step = 39900 (0.065 sec)
# INFO:tensorflow:loss = 18.872822, step = 39900 (0.065 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 40000...
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 40000...
# INFO:tensorflow:Saving checkpoints for 40000 into modele/autompg-dnnregresor/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 40000 into modele/autompg-dnnregresor/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 40000...
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 40000...
# INFO:tensorflow:Loss for final step: 12.215286.
# INFO:tensorflow:Loss for final step: 12.215286.

# %%
reloaded_regressor = tf.estimator.DNNRegressor(
    feature_columns=all_feature_columns,
    hidden_units=[32, 10],
    warm_start_from='modele/autompg-dnnregresor/',
    model_dir='modele/autompg-dnnregresor/')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'modele/autompg-dnnregresor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': 'modele/autompg-dnnregresor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def eval_input_fn(df_test, batch_size=8):
    df = df_test.copy()
    test_x, test_y = df, df.pop('Spalanie')
    dataset = tf.data.Dataset.from_tensor_slices((dict(test_x), test_y))

    return dataset.batch(batch_size)

eval_results = reloaded_regressor.evaluate(
    input_fn=lambda:eval_input_fn(df_test_norm, batch_size=8))

for key in eval_results:
    print('{:15s} {}'.format(key, eval_results[key]))
    
print('Średnia funkcja straty {:.4f}'.format(eval_results['average_loss']))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-09-24T04:06:25Z
# INFO:tensorflow:Starting evaluation at 2021-09-24T04:06:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from modele/autompg-dnnregresor/model.ckpt-40000
# INFO:tensorflow:Restoring parameters from modele/autompg-dnnregresor/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.34434s
# INFO:tensorflow:Inference Time : 0.34434s
# INFO:tensorflow:Finished evaluation at 2021-09-24-04:06:25
# INFO:tensorflow:Finished evaluation at 2021-09-24-04:06:25
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 21.961758, global_step = 40000, label/mean = 23.611393, loss = 21.784882, prediction/mean = 21.662764
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 21.961758, global_step = 40000, label/mean = 23.611393, loss = 21.784882, prediction/mean = 21.662764
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: modele/autompg-dnnregresor/model.ckpt-40000
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: modele/autompg-dnnregresor/model.ckpt-40000
# average_loss    21.96175765991211
# label/mean      23.611392974853516
# loss            21.784881591796875
# prediction/mean 21.662763595581055
# global_step     40000
# Średnia funkcja straty 21.9618

# %%
pred_res = regressor.predict(input_fn=lambda: eval_input_fn(df_test_norm, batch_size=8))

print(next(iter(pred_res)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from modele/autompg-dnnregresor/model.ckpt-40000
# INFO:tensorflow:Restoring parameters from modele/autompg-dnnregresor/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([23.228271], dtype=float32)}

# %% [markdown]
# #### Regresor wzmocnionego drzewa

# %%
boosted_tree = tf.estimator.BoostedTreesRegressor(
    feature_columns=all_feature_columns,
    n_batches_per_layer=20,
    n_trees=200)

boosted_tree.train(
    input_fn=lambda:train_input_fn(df_train_norm, batch_size=BATCH_SIZE))

eval_results = boosted_tree.evaluate(
    input_fn=lambda:eval_input_fn(df_test_norm, batch_size=8))

print(eval_results)

print('Średnia funkcja straty {:.4f}'.format(eval_results['average_loss']))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\fraktal\AppData\Local\Temp\tmpnnl2sjof
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\fraktal\AppData\Local\Temp\tmpnnl2sjof
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\fraktal\\AppData\\Local\\Temp\\tmpnnl2sjof', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\fraktal\\AppData\\Local\\Temp\\tmpnnl2sjof', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\canned\boosted_trees.py:398: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From C:\Users\fraktal\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\canned\boosted_trees.py:398: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-148-976c03cd75fb> in <module>
#       4     n_trees=200)
#       5
# ----> 6 boosted_tree.train(
#       7     input_fn=lambda:train_input_fn(df_train_norm, batch_size=BATCH_SIZE))
#       8
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     347
#     348       saving_listeners = _check_listeners_type(saving_listeners)
# --> 349       loss = self._train_model(input_fn, hooks, saving_listeners)
#     350       logging.info('Loss for final step: %s.', loss)
#     351       return self
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1173       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1174     else:
# -> 1175       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1176
#    1177   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1201           self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1202       worker_hooks.extend(input_hooks)
# -> 1203       estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1204                                            self.config)
#    1205       global_step_tensor = tf.compat.v1.train.get_global_step(g)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1161
#    1162     logging.info('Calling model_fn.')
# -> 1163     model_fn_results = self._model_fn(features=features, **kwargs)
#    1164     logging.info('Done calling model_fn.')
#    1165
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\canned\boosted_trees.py in _model_fn(features, labels, mode, config)
#    2231
#    2232     def _model_fn(features, labels, mode, config):
# -> 2233       return _bt_model_fn(
#    2234           features,
#    2235           labels,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\canned\boosted_trees.py in _bt_model_fn(features, labels, mode, head, feature_columns, tree_hparams, n_batches_per_layer, config, closed_form_grad_and_hess_fn, example_id_column_name, weight_column, train_in_memory, name)
#    1259       batch_size = tf.compat.v1.shape(labels)[0]
#    1260       cached_tree_ids, cached_node_ids, cached_logits = (
# -> 1261           tf.zeros([batch_size], dtype=tf.dtypes.int32),
#    1262           _DUMMY_NODE_ID * tf.ones([batch_size], dtype=tf.dtypes.int32),
#    1263           tf.zeros([batch_size, logits_dimension], dtype=tf.dtypes.float32))
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in wrapped(*args, **kwargs)
#    2817
#    2818   def wrapped(*args, **kwargs):
# -> 2819     tensor = fun(*args, **kwargs)
#    2820     tensor._is_zeros_tensor = True
#    2821     return tensor
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in zeros(shape, dtype, name)
#    2866           # Create a constant if it won't be very big. Otherwise create a fill
#    2867           # op to prevent serialized GraphDefs from becoming too large.
# -> 2868           output = _constant_if_small(zero, shape, dtype, name)
#    2869           if output is not None:
#    2870             return output
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in _constant_if_small(value, shape, dtype, name)
#    2802 def _constant_if_small(value, shape, dtype, name):
#    2803   try:
# -> 2804     if np.prod(shape) < 1000:
#    2805       return constant(value, shape=shape, dtype=dtype, name=name)
#    2806   except TypeError:
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    3028     10
#    3029     """
# -> 3030     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3031                           keepdims=keepdims, initial=initial, where=where)
#    3032
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\ops.py in __array__(self)
#     850
#     851   def __array__(self):
# --> 852     raise NotImplementedError(
#     853         "Cannot convert a symbolic Tensor ({}) to a numpy array."
#     854         " This error may indicate that you're trying to pass a Tensor to"
#
# NotImplementedError: Cannot convert a symbolic Tensor (boosted_trees/strided_slice:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported
