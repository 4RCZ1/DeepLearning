# %% [markdown]
# ---
# ---
# # Tensorflow 2 - wstęp
#
# ---
# ---

# %% [markdown]
# ### Spis treści:
#
# [2. Tensorflow 2 - informacje elementarne](tf2_typy_zmienne.ipynb)
#
# [3. Tensorflow 2 - sieci jednokierunkowe](tf2_keras.ipynb)
